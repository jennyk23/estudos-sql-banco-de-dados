# %% [markdown]
# <a href="https://colab.research.google.com/github/jennyk23/Magpy/blob/main/NomeSobrenome_Sakila_SQL_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade Sakila PT-BR — execução completa no Google Colab
#
# Este notebook:
# 1. instala e inicia o MariaDB;
# 2. baixa e importa a base oficial Sakila;
# 3. cria a base `locadora` com tabelas e colunas em português;
# 4. executa todos os exercícios, procedures e triggers;
# 5. permite baixar o arquivo SQL final.
#
# **Execute as células na ordem.**

# %%
import os
import shutil
import subprocess
import time

def executar(comando, *, entrada=None, verificar=True):
    resultado = subprocess.run(
        comando,
        stdin=entrada,
        text=True,
        capture_output=True
    )
    if verificar and resultado.returncode != 0:
        print(resultado.stdout)
        print(resultado.stderr)
        raise RuntimeError(
            "Falha ao executar: " + " ".join(comando)
        )
    return resultado

if shutil.which("mariadb") is None:
    print("Instalando MariaDB e utilitários...")
    subprocess.run(
        ["apt-get", "update", "-qq"],
        check=True
    )
    subprocess.run(
        [
            "apt-get",
            "install",
            "-y",
            "mariadb-server",
            "mariadb-client",
            "unzip"
        ],
        check=True,
        stdout=subprocess.DEVNULL
    )

os.makedirs("/run/mysqld", exist_ok=True)
subprocess.run(
    ["chown", "mysql:mysql", "/run/mysqld"],
    check=False
)
subprocess.run(
    ["service", "mariadb", "start"],
    check=False,
    stdout=subprocess.DEVNULL,
    stderr=subprocess.DEVNULL
)

for _ in range(30):
    teste = executar(
        [
            "mariadb-admin",
            "-u",
            "root",
            "ping",
            "--silent"
        ],
        verificar=False
    )
    if teste.returncode == 0:
        break
    time.sleep(1)
else:
    raise RuntimeError(
        "Não foi possível iniciar o MariaDB."
    )

print("MariaDB iniciado com sucesso.")
print(
    executar(
        ["mariadb", "--version"]
    ).stdout
)
# Out:
# Instalando MariaDB e utilitários...
# MariaDB iniciado com sucesso.
# mariadb  Ver 15.1 Distrib 10.6.23-MariaDB, for debian-linux-gnu (x86_64) using  EditLine wrapper

# %%
from pathlib import Path
from urllib.request import urlretrieve
import zipfile
import subprocess

url = "https://downloads.mysql.com/docs/sakila-db.zip"
zip_path = Path("/content/sakila-db.zip")
extract_dir = Path("/content/sakila-db-extraido")

print("Baixando a base oficial Sakila...")
urlretrieve(url, zip_path)

extract_dir.mkdir(
    parents=True,
    exist_ok=True
)

with zipfile.ZipFile(zip_path, "r") as arquivo_zip:
    arquivo_zip.extractall(extract_dir)

schema_files = list(
    extract_dir.rglob("sakila-schema.sql")
)
data_files = list(
    extract_dir.rglob("sakila-data.sql")
)

if not schema_files or not data_files:
    raise FileNotFoundError(
        "Os arquivos oficiais da base Sakila não foram encontrados."
    )

schema_path = schema_files[0]
data_path = data_files[0]

print("Importando a estrutura oficial...")
with schema_path.open("r", encoding="utf-8", errors="replace") as entrada:
    resultado = subprocess.run(
        [
            "mariadb",
            "-u",
            "root",
            "--default-character-set=utf8mb4"
        ],
        stdin=entrada,
        text=True,
        capture_output=True
    )

if resultado.returncode != 0:
    print(resultado.stderr)
    raise RuntimeError(
        "Falha ao importar sakila-schema.sql."
    )

print("Importando os dados oficiais...")
with data_path.open("r", encoding="utf-8", errors="replace") as entrada:
    resultado = subprocess.run(
        [
            "mariadb",
            "-u",
            "root",
            "--default-character-set=utf8mb4"
        ],
        stdin=entrada,
        text=True,
        capture_output=True
    )

if resultado.returncode != 0:
    print(resultado.stderr)
    raise RuntimeError(
        "Falha ao importar sakila-data.sql."
    )

print("Base oficial sakila importada com sucesso.")
# Out:
# Baixando a base oficial Sakila...
# Importando a estrutura oficial...
# Importando os dados oficiais...
# Base oficial sakila importada com sucesso.

# %%
from pathlib import Path
import subprocess

setup_sql = "\n-- ============================================================\n-- PREPARAÇÃO DA BASE SAKILA PT-BR PARA A ATIVIDADE\n-- Origem dos dados: banco oficial sakila\n-- Banco usado nos exercícios: locadora\n-- ============================================================\n\nDROP DATABASE IF EXISTS locadora;\n\nCREATE DATABASE locadora\n    CHARACTER SET utf8mb4\n    COLLATE utf8mb4_unicode_ci;\n\nUSE locadora;\n\nCREATE TABLE pais (\n    pais_id SMALLINT UNSIGNED NOT NULL,\n    pais VARCHAR(50) NOT NULL,\n    PRIMARY KEY (pais_id)\n) ENGINE = InnoDB;\n\nCREATE TABLE cidade (\n    cidade_id SMALLINT UNSIGNED NOT NULL,\n    cidade VARCHAR(50) NOT NULL,\n    pais_id SMALLINT UNSIGNED NOT NULL,\n    PRIMARY KEY (cidade_id),\n    CONSTRAINT fk_cidade_pais\n        FOREIGN KEY (pais_id)\n        REFERENCES pais(pais_id)\n) ENGINE = InnoDB;\n\nCREATE TABLE endereco (\n    endereco_id SMALLINT UNSIGNED NOT NULL,\n    endereco VARCHAR(100) NOT NULL,\n    cidade_id SMALLINT UNSIGNED NOT NULL,\n    PRIMARY KEY (endereco_id),\n    CONSTRAINT fk_endereco_cidade\n        FOREIGN KEY (cidade_id)\n        REFERENCES cidade(cidade_id)\n) ENGINE = InnoDB;\n\nCREATE TABLE cliente (\n    cliente_id SMALLINT UNSIGNED NOT NULL,\n    primeiro_nome VARCHAR(45) NOT NULL,\n    ultimo_nome VARCHAR(45) NOT NULL,\n    email VARCHAR(50),\n    endereco_id SMALLINT UNSIGNED NOT NULL,\n    PRIMARY KEY (cliente_id),\n    CONSTRAINT fk_cliente_endereco\n        FOREIGN KEY (endereco_id)\n        REFERENCES endereco(endereco_id)\n) ENGINE = InnoDB;\n\nCREATE TABLE ator (\n    ator_id SMALLINT UNSIGNED NOT NULL,\n    primeiro_nome VARCHAR(45) NOT NULL,\n    ultimo_nome VARCHAR(45) NOT NULL,\n    PRIMARY KEY (ator_id)\n) ENGINE = InnoDB;\n\nCREATE TABLE categoria (\n    categoria_id TINYINT UNSIGNED NOT NULL,\n    nome VARCHAR(25) NOT NULL,\n    PRIMARY KEY (categoria_id)\n) ENGINE = InnoDB;\n\nCREATE TABLE filme (\n    filme_id SMALLINT UNSIGNED NOT NULL AUTO_INCREMENT,\n    titulo VARCHAR(128) NOT NULL,\n    descricao TEXT,\n    ano_lancamento YEAR,\n    idioma_id TINYINT UNSIGNED NOT NULL,\n    duracao_locacao TINYINT UNSIGNED NOT NULL DEFAULT 3,\n    preco_da_locacao DECIMAL(4,2) NOT NULL DEFAULT 4.99,\n    duracao_do_filme SMALLINT UNSIGNED,\n    custo_substituicao DECIMAL(5,2) NOT NULL DEFAULT 19.99,\n    classificacao VARCHAR(10),\n    PRIMARY KEY (filme_id),\n    CONSTRAINT chk_filme_preco_nao_negativo\n        CHECK (preco_da_locacao >= 0)\n) ENGINE = InnoDB;\n\nCREATE TABLE filme_categoria (\n    filme_id SMALLINT UNSIGNED NOT NULL,\n    categoria_id TINYINT UNSIGNED NOT NULL,\n    PRIMARY KEY (filme_id, categoria_id),\n    CONSTRAINT fk_filme_categoria_filme\n        FOREIGN KEY (filme_id)\n        REFERENCES filme(filme_id)\n        ON DELETE CASCADE,\n    CONSTRAINT fk_filme_categoria_categoria\n        FOREIGN KEY (categoria_id)\n        REFERENCES categoria(categoria_id)\n) ENGINE = InnoDB;\n\nCREATE TABLE filme_ator (\n    ator_id SMALLINT UNSIGNED NOT NULL,\n    filme_id SMALLINT UNSIGNED NOT NULL,\n    PRIMARY KEY (ator_id, filme_id),\n    CONSTRAINT fk_filme_ator_ator\n        FOREIGN KEY (ator_id)\n        REFERENCES ator(ator_id),\n    CONSTRAINT fk_filme_ator_filme\n        FOREIGN KEY (filme_id)\n        REFERENCES filme(filme_id)\n        ON DELETE CASCADE\n) ENGINE = InnoDB;\n\nCREATE TABLE inventario (\n    inventario_id MEDIUMINT UNSIGNED NOT NULL,\n    filme_id SMALLINT UNSIGNED NOT NULL,\n    PRIMARY KEY (inventario_id),\n    CONSTRAINT fk_inventario_filme\n        FOREIGN KEY (filme_id)\n        REFERENCES filme(filme_id)\n) ENGINE = InnoDB;\n\nCREATE TABLE aluguel (\n    aluguel_id INT NOT NULL,\n    data_aluguel DATETIME NOT NULL,\n    inventario_id MEDIUMINT UNSIGNED NOT NULL,\n    cliente_id SMALLINT UNSIGNED NOT NULL,\n    data_devolucao DATETIME,\n    PRIMARY KEY (aluguel_id),\n    CONSTRAINT fk_aluguel_inventario\n        FOREIGN KEY (inventario_id)\n        REFERENCES inventario(inventario_id),\n    CONSTRAINT fk_aluguel_cliente\n        FOREIGN KEY (cliente_id)\n        REFERENCES cliente(cliente_id)\n) ENGINE = InnoDB;\n\nCREATE TABLE pagamento (\n    pagamento_id SMALLINT UNSIGNED NOT NULL AUTO_INCREMENT,\n    cliente_id SMALLINT UNSIGNED NOT NULL,\n    aluguel_id INT,\n    valor DECIMAL(5,2) NOT NULL,\n    data_pagamento DATETIME NOT NULL,\n    PRIMARY KEY (pagamento_id),\n    CONSTRAINT fk_pagamento_cliente\n        FOREIGN KEY (cliente_id)\n        REFERENCES cliente(cliente_id),\n    CONSTRAINT fk_pagamento_aluguel\n        FOREIGN KEY (aluguel_id)\n        REFERENCES aluguel(aluguel_id)\n) ENGINE = InnoDB;\n\nINSERT INTO pais (pais_id, pais)\nSELECT country_id, country\nFROM sakila.country;\n\nINSERT INTO cidade (cidade_id, cidade, pais_id)\nSELECT city_id, city, country_id\nFROM sakila.city;\n\nINSERT INTO endereco (endereco_id, endereco, cidade_id)\nSELECT address_id, address, city_id\nFROM sakila.address;\n\nINSERT INTO cliente (\n    cliente_id,\n    primeiro_nome,\n    ultimo_nome,\n    email,\n    endereco_id\n)\nSELECT\n    customer_id,\n    first_name,\n    last_name,\n    email,\n    address_id\nFROM sakila.customer;\n\nINSERT INTO ator (\n    ator_id,\n    primeiro_nome,\n    ultimo_nome\n)\nSELECT\n    actor_id,\n    first_name,\n    last_name\nFROM sakila.actor;\n\nINSERT INTO categoria (\n    categoria_id,\n    nome\n)\nSELECT\n    category_id,\n    name\nFROM sakila.category;\n\nINSERT INTO filme (\n    filme_id,\n    titulo,\n    descricao,\n    ano_lancamento,\n    idioma_id,\n    duracao_locacao,\n    preco_da_locacao,\n    duracao_do_filme,\n    custo_substituicao,\n    classificacao\n)\nSELECT\n    film_id,\n    title,\n    description,\n    release_year,\n    language_id,\n    rental_duration,\n    rental_rate,\n    length,\n    replacement_cost,\n    CAST(rating AS CHAR)\nFROM sakila.film;\n\nINSERT INTO filme_categoria (\n    filme_id,\n    categoria_id\n)\nSELECT\n    film_id,\n    category_id\nFROM sakila.film_category;\n\nINSERT INTO filme_ator (\n    ator_id,\n    filme_id\n)\nSELECT\n    actor_id,\n    film_id\nFROM sakila.film_actor;\n\nINSERT INTO inventario (\n    inventario_id,\n    filme_id\n)\nSELECT\n    inventory_id,\n    film_id\nFROM sakila.inventory;\n\nINSERT INTO aluguel (\n    aluguel_id,\n    data_aluguel,\n    inventario_id,\n    cliente_id,\n    data_devolucao\n)\nSELECT\n    rental_id,\n    rental_date,\n    inventory_id,\n    customer_id,\n    return_date\nFROM sakila.rental;\n\nINSERT INTO pagamento (\n    pagamento_id,\n    cliente_id,\n    aluguel_id,\n    valor,\n    data_pagamento\n)\nSELECT\n    payment_id,\n    customer_id,\n    rental_id,\n    amount,\n    payment_date\nFROM sakila.payment;\n\nALTER TABLE filme AUTO_INCREMENT = 2000;\nALTER TABLE pagamento AUTO_INCREMENT = 20000;\n\nSELECT\n    'Base locadora PT-BR criada com sucesso.' AS mensagem;\n\nSHOW TABLES;\n"

setup_path = Path(
    "/content/00_preparar_locadora_sakila_ptbr.sql"
)
setup_path.write_text(
    setup_sql,
    encoding="utf-8"
)

with setup_path.open("r", encoding="utf-8") as entrada:
    resultado = subprocess.run(
        [
            "mariadb",
            "-u",
            "root",
            "--default-character-set=utf8mb4"
        ],
        stdin=entrada,
        text=True,
        capture_output=True
    )

print(resultado.stdout)

if resultado.returncode != 0:
    print(resultado.stderr)
    raise RuntimeError(
        "Falha ao criar a base locadora em português."
    )

print("Base locadora PT-BR preparada com sucesso.")
# Out:
# mensagem
# Base locadora PT-BR criada com sucesso.
# Tables_in_locadora
# aluguel
# ator
# categoria
# cidade
# cliente
# endereco
# filme
# filme_ator
# filme_categoria
# inventario
# pagamento
# pais
#
# Base locadora PT-BR preparada com sucesso.

# %%
from pathlib import Path
import subprocess

solucoes_sql = "\n-- =====================================================================\n-- ATIVIDADES PRÁTICAS – BASE SAKILA PT-BR\n-- Consultas, Stored Procedures e Triggers\n--\n-- Renomeie o arquivo conforme o padrão:\n-- NomeSobrenome_Sakila_SQL.sql\n-- =====================================================================\n\nUSE locadora;\n\n-- =====================================================================\n-- ETAPA 0 – PREPARAÇÃO\n-- =====================================================================\n\nSHOW TABLES;\n\nSELECT * FROM filme LIMIT 10;\nSELECT * FROM cliente LIMIT 10;\nSELECT * FROM aluguel LIMIT 10;\n\n\n-- =====================================================================\n-- PARTE I – CONSULTAS INTERMEDIÁRIAS\n-- =====================================================================\n\n-- ---------------------------------------------------------------------\n-- EXERCÍCIO 1 – FILMES E CATEGORIAS\n-- ---------------------------------------------------------------------\n\nSELECT\n    f.filme_id,\n    f.titulo,\n    c.nome AS categoria\nFROM filme AS f\nINNER JOIN filme_categoria AS fc\n    ON fc.filme_id = f.filme_id\nINNER JOIN categoria AS c\n    ON c.categoria_id = fc.categoria_id\nORDER BY\n    f.titulo,\n    c.nome;\n\n\n-- ---------------------------------------------------------------------\n-- EXERCÍCIO 2 – CLIENTES QUE MAIS ALUGARAM\n-- ---------------------------------------------------------------------\n\nSELECT\n    c.cliente_id,\n    CONCAT_WS(\n        ' ',\n        c.primeiro_nome,\n        c.ultimo_nome\n    ) AS cliente,\n    COUNT(a.aluguel_id) AS total_alugueis\nFROM cliente AS c\nINNER JOIN aluguel AS a\n    ON a.cliente_id = c.cliente_id\nGROUP BY\n    c.cliente_id,\n    c.primeiro_nome,\n    c.ultimo_nome\nORDER BY\n    total_alugueis DESC,\n    cliente ASC\nLIMIT 20;\n\n\n-- ---------------------------------------------------------------------\n-- EXERCÍCIO 3 – FILMES LONGOS\n-- ---------------------------------------------------------------------\n\nSELECT\n    filme_id,\n    titulo,\n    duracao_do_filme,\n    preco_da_locacao\nFROM filme\nWHERE duracao_do_filme > 120\nORDER BY\n    duracao_do_filme DESC,\n    titulo ASC;\n\n\n-- ---------------------------------------------------------------------\n-- EXERCÍCIO 4 – QUANTIDADE DE FILMES POR CATEGORIA\n-- ---------------------------------------------------------------------\n\nSELECT\n    c.categoria_id,\n    c.nome AS categoria,\n    COUNT(fc.filme_id) AS quantidade_filmes\nFROM categoria AS c\nLEFT JOIN filme_categoria AS fc\n    ON fc.categoria_id = c.categoria_id\nGROUP BY\n    c.categoria_id,\n    c.nome\nORDER BY\n    quantidade_filmes DESC,\n    c.nome ASC;\n\n\n-- =====================================================================\n-- PARTE II – CONSULTAS AVANÇADAS\n-- =====================================================================\n\n-- ---------------------------------------------------------------------\n-- EXERCÍCIO 5 – ATORES MAIS PRESENTES\n-- ---------------------------------------------------------------------\n\nSELECT\n    a.ator_id,\n    CONCAT_WS(\n        ' ',\n        a.primeiro_nome,\n        a.ultimo_nome\n    ) AS ator,\n    COUNT(fa.filme_id) AS quantidade_filmes\nFROM ator AS a\nINNER JOIN filme_ator AS fa\n    ON fa.ator_id = a.ator_id\nGROUP BY\n    a.ator_id,\n    a.primeiro_nome,\n    a.ultimo_nome\nHAVING COUNT(fa.filme_id) > 25\nORDER BY\n    quantidade_filmes DESC,\n    ator ASC;\n\n\n-- ---------------------------------------------------------------------\n-- EXERCÍCIO 6 – CLIENTES VIP\n-- ---------------------------------------------------------------------\n\nSELECT\n    c.cliente_id,\n    CONCAT_WS(\n        ' ',\n        c.primeiro_nome,\n        c.ultimo_nome\n    ) AS cliente,\n    ROUND(\n        SUM(p.valor),\n        2\n    ) AS gasto_total\nFROM cliente AS c\nINNER JOIN pagamento AS p\n    ON p.cliente_id = c.cliente_id\nGROUP BY\n    c.cliente_id,\n    c.primeiro_nome,\n    c.ultimo_nome\nHAVING SUM(p.valor) > 150.00\nORDER BY\n    gasto_total DESC,\n    cliente ASC;\n\n\n-- ---------------------------------------------------------------------\n-- EXERCÍCIO 7 – FILMES MAIS LUCRATIVOS\n-- ---------------------------------------------------------------------\n\nSELECT\n    f.filme_id,\n    f.titulo,\n    ROUND(\n        SUM(p.valor),\n        2\n    ) AS receita_total,\n    COUNT(DISTINCT a.aluguel_id) AS total_alugueis\nFROM pagamento AS p\nINNER JOIN aluguel AS a\n    ON a.aluguel_id = p.aluguel_id\nINNER JOIN inventario AS i\n    ON i.inventario_id = a.inventario_id\nINNER JOIN filme AS f\n    ON f.filme_id = i.filme_id\nGROUP BY\n    f.filme_id,\n    f.titulo\nORDER BY\n    receita_total DESC,\n    f.titulo ASC\nLIMIT 5;\n\n\n-- =====================================================================\n-- TABELAS AUXILIARES DAS TRIGGERS E DO DESAFIO FINAL\n-- =====================================================================\n\nDROP TRIGGER IF EXISTS trg_auditoria_filme_update;\nDROP TRIGGER IF EXISTS trg_validar_preco_filme_insert;\nDROP TRIGGER IF EXISTS trg_atualizar_resumo_gasto_pagamento;\n\nDROP PROCEDURE IF EXISTS clientes_por_pais;\nDROP PROCEDURE IF EXISTS total_alugueis_cliente;\nDROP PROCEDURE IF EXISTS atualizar_resumo_gasto_clientes;\n\nDROP TABLE IF EXISTS auditoria_filme;\nDROP TABLE IF EXISTS resumo_gasto_cliente;\n\nCREATE TABLE auditoria_filme (\n    auditoria_id BIGINT AUTO_INCREMENT,\n    filme_id INT NOT NULL,\n    titulo_anterior VARCHAR(255),\n    titulo_novo VARCHAR(255),\n    preco_anterior DECIMAL(10,2),\n    preco_novo DECIMAL(10,2),\n    data_alteracao DATETIME NOT NULL\n        DEFAULT CURRENT_TIMESTAMP,\n    tipo_operacao VARCHAR(20) NOT NULL,\n    usuario_banco VARCHAR(100),\n\n    CONSTRAINT pk_auditoria_filme\n        PRIMARY KEY (auditoria_id)\n) ENGINE = InnoDB;\n\nCREATE TABLE resumo_gasto_cliente (\n    cliente_id INT NOT NULL,\n    total_gasto DECIMAL(12,2) NOT NULL\n        DEFAULT 0.00,\n    quantidade_pagamentos INT NOT NULL\n        DEFAULT 0,\n    atualizado_em DATETIME NOT NULL\n        DEFAULT CURRENT_TIMESTAMP,\n\n    CONSTRAINT pk_resumo_gasto_cliente\n        PRIMARY KEY (cliente_id)\n) ENGINE = InnoDB;\n\n\n-- =====================================================================\n-- PARTE III – STORED PROCEDURES\n-- =====================================================================\n\nDELIMITER $$\n\n-- ---------------------------------------------------------------------\n-- EXERCÍCIO 8 – PROCEDURE POR PAÍS\n-- ---------------------------------------------------------------------\n\nCREATE PROCEDURE clientes_por_pais(\n    IN p_nome_pais VARCHAR(50)\n)\nBEGIN\n    SELECT\n        c.cliente_id,\n        CONCAT_WS(\n            ' ',\n            c.primeiro_nome,\n            c.ultimo_nome\n        ) AS cliente,\n        c.email,\n        ci.cidade,\n        p.pais\n    FROM cliente AS c\n    INNER JOIN endereco AS e\n        ON e.endereco_id = c.endereco_id\n    INNER JOIN cidade AS ci\n        ON ci.cidade_id = e.cidade_id\n    INNER JOIN pais AS p\n        ON p.pais_id = ci.pais_id\n    WHERE p.pais = TRIM(p_nome_pais)\n    ORDER BY\n        c.primeiro_nome,\n        c.ultimo_nome;\nEND$$\n\n\n-- ---------------------------------------------------------------------\n-- EXERCÍCIO 9 – QUANTIDADE DE ALUGUÉIS\n-- ---------------------------------------------------------------------\n\nCREATE PROCEDURE total_alugueis_cliente(\n    IN p_cliente_id INT\n)\nBEGIN\n    DECLARE v_cliente_existe INT DEFAULT 0;\n\n    SELECT COUNT(*)\n    INTO v_cliente_existe\n    FROM cliente\n    WHERE cliente_id = p_cliente_id;\n\n    IF v_cliente_existe = 0 THEN\n        SIGNAL SQLSTATE '45000'\n        SET MESSAGE_TEXT =\n            'Cliente não encontrado.';\n    END IF;\n\n    SELECT\n        c.cliente_id,\n        CONCAT_WS(\n            ' ',\n            c.primeiro_nome,\n            c.ultimo_nome\n        ) AS cliente,\n        COUNT(a.aluguel_id) AS total_alugueis\n    FROM cliente AS c\n    LEFT JOIN aluguel AS a\n        ON a.cliente_id = c.cliente_id\n    WHERE c.cliente_id = p_cliente_id\n    GROUP BY\n        c.cliente_id,\n        c.primeiro_nome,\n        c.ultimo_nome;\nEND$$\n\n\n-- ---------------------------------------------------------------------\n-- DESAFIO FINAL – PROCEDURE DE RESUMO DE GASTOS\n-- ---------------------------------------------------------------------\n\nCREATE PROCEDURE atualizar_resumo_gasto_clientes()\nBEGIN\n    DELETE FROM resumo_gasto_cliente;\n\n    INSERT INTO resumo_gasto_cliente (\n        cliente_id,\n        total_gasto,\n        quantidade_pagamentos,\n        atualizado_em\n    )\n    SELECT\n        c.cliente_id,\n        COALESCE(\n            ROUND(SUM(p.valor), 2),\n            0.00\n        ),\n        COUNT(p.pagamento_id),\n        CURRENT_TIMESTAMP\n    FROM cliente AS c\n    LEFT JOIN pagamento AS p\n        ON p.cliente_id = c.cliente_id\n    GROUP BY\n        c.cliente_id;\nEND$$\n\n\n-- =====================================================================\n-- PARTE IV – TRIGGERS\n-- =====================================================================\n\n-- ---------------------------------------------------------------------\n-- EXERCÍCIO 10 – AUDITORIA DE FILMES\n-- OLD = valores anteriores.\n-- NEW = valores posteriores.\n-- ---------------------------------------------------------------------\n\nCREATE TRIGGER trg_auditoria_filme_update\nAFTER UPDATE ON filme\nFOR EACH ROW\nBEGIN\n    INSERT INTO auditoria_filme (\n        filme_id,\n        titulo_anterior,\n        titulo_novo,\n        preco_anterior,\n        preco_novo,\n        data_alteracao,\n        tipo_operacao,\n        usuario_banco\n    ) VALUES (\n        OLD.filme_id,\n        OLD.titulo,\n        NEW.titulo,\n        OLD.preco_da_locacao,\n        NEW.preco_da_locacao,\n        CURRENT_TIMESTAMP,\n        'UPDATE',\n        CURRENT_USER()\n    );\nEND$$\n\n\n-- ---------------------------------------------------------------------\n-- EXERCÍCIO 11 – VALIDAÇÃO DE PREÇO\n-- ---------------------------------------------------------------------\n\nCREATE TRIGGER trg_validar_preco_filme_insert\nBEFORE INSERT ON filme\nFOR EACH ROW\nBEGIN\n    IF NEW.preco_da_locacao IS NULL\n       OR NEW.preco_da_locacao < 1.00 THEN\n\n        SIGNAL SQLSTATE '45000'\n        SET MESSAGE_TEXT =\n            'Preço de locação inválido. O valor mínimo permitido é R$ 1,00.';\n    END IF;\nEND$$\n\n\n-- ---------------------------------------------------------------------\n-- DESAFIO FINAL – TRIGGER DO RESUMO DE GASTOS\n-- ---------------------------------------------------------------------\n\nCREATE TRIGGER trg_atualizar_resumo_gasto_pagamento\nAFTER INSERT ON pagamento\nFOR EACH ROW\nBEGIN\n    INSERT INTO resumo_gasto_cliente (\n        cliente_id,\n        total_gasto,\n        quantidade_pagamentos,\n        atualizado_em\n    ) VALUES (\n        NEW.cliente_id,\n        NEW.valor,\n        1,\n        CURRENT_TIMESTAMP\n    )\n    ON DUPLICATE KEY UPDATE\n        total_gasto =\n            total_gasto + NEW.valor,\n        quantidade_pagamentos =\n            quantidade_pagamentos + 1,\n        atualizado_em =\n            CURRENT_TIMESTAMP;\nEND$$\n\nDELIMITER ;\n\n\n-- =====================================================================\n-- DEMONSTRAÇÃO DAS PROCEDURES\n-- =====================================================================\n\nCALL clientes_por_pais('Brazil');\n\nCALL total_alugueis_cliente(15);\n\n\n-- =====================================================================\n-- DEMONSTRAÇÃO DA AUDITORIA\n-- =====================================================================\n\nSTART TRANSACTION;\n\nUPDATE filme\nSET preco_da_locacao =\n    preco_da_locacao + 0.10\nWHERE filme_id = 1;\n\nSELECT\n    auditoria_id,\n    filme_id,\n    titulo_anterior,\n    titulo_novo,\n    preco_anterior,\n    preco_novo,\n    data_alteracao,\n    tipo_operacao,\n    usuario_banco\nFROM auditoria_filme\nWHERE filme_id = 1\nORDER BY auditoria_id DESC;\n\nROLLBACK;\n\n\n-- =====================================================================\n-- TESTE DA VALIDAÇÃO DE PREÇO\n-- Este comando permanece comentado porque gera erro proposital.\n-- Execute-o separadamente para comprovar a trigger.\n-- =====================================================================\n\n-- INSERT INTO filme (\n--     titulo,\n--     idioma_id,\n--     preco_da_locacao\n-- ) VALUES (\n--     'FILME COM PRECO INVALIDO',\n--     1,\n--     0.50\n-- );\n\n\n-- =====================================================================\n-- DESAFIO FINAL – RESUMO DE GASTOS\n-- =====================================================================\n\nCALL atualizar_resumo_gasto_clientes();\n\nSELECT\n    c.cliente_id,\n    CONCAT_WS(\n        ' ',\n        c.primeiro_nome,\n        c.ultimo_nome\n    ) AS cliente,\n    r.total_gasto,\n    r.quantidade_pagamentos,\n    r.atualizado_em\nFROM cliente AS c\nINNER JOIN resumo_gasto_cliente AS r\n    ON r.cliente_id = c.cliente_id\nWHERE r.total_gasto > 150.00\nORDER BY\n    r.total_gasto DESC,\n    cliente ASC;\n\n\n-- =====================================================================\n-- VERIFICAÇÃO DOS OBJETOS CRIADOS\n-- =====================================================================\n\nSHOW PROCEDURE STATUS\nWHERE Db = 'locadora'\n  AND Name IN (\n      'clientes_por_pais',\n      'total_alugueis_cliente',\n      'atualizar_resumo_gasto_clientes'\n  );\n\nSHOW TRIGGERS\nFROM locadora;\n\n\n-- =====================================================================\n-- EXPLICAÇÃO DO DESAFIO FINAL\n--\n-- A procedure utiliza JOIN e GROUP BY para consolidar o total gasto e\n-- a quantidade de pagamentos de cada cliente.\n--\n-- A trigger mantém o resumo atualizado após cada novo pagamento.\n--\n-- Em um sistema real, a solução pode alimentar painéis gerenciais,\n-- programas de fidelidade, campanhas e identificação de clientes VIP.\n-- =====================================================================\n"

arquivo_solucoes = Path(
    "/content/NomeSobrenome_Sakila_SQL.sql"
)
arquivo_solucoes.write_text(
    solucoes_sql,
    encoding="utf-8"
)

with arquivo_solucoes.open(
    "r",
    encoding="utf-8"
) as entrada:
    resultado = subprocess.run(
        [
            "mariadb",
            "-u",
            "root",
            "--default-character-set=utf8mb4"
        ],
        stdin=entrada,
        text=True,
        capture_output=True
    )

print(resultado.stdout)

if resultado.returncode != 0:
    print("ERRO DO MYSQL/MARIADB:")
    print(resultado.stderr)
    raise RuntimeError(
        "Falha ao executar as soluções da atividade."
    )

print(
    "Consultas, procedures e triggers executadas com sucesso."
)
print(
    "Arquivo SQL criado em:",
    arquivo_solucoes
)
# Out:
# Tables_in_locadora
# aluguel
# ator
# auditoria_filme
# categoria
# cidade
# cliente
# endereco
# filme
# filme_ator
# filme_categoria
# inventario
# pagamento
# pais
# resumo_gasto_cliente
# filme_id	titulo	descricao	ano_lancamento	idioma_id	duracao_locacao	preco_da_locacao	duracao_do_filme	custo_substituicao	classificacao
# 1	ACADEMY DINOSAUR	A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies	2006	1	6	0.99	86	20.99	PG
# 2	ACE GOLDFINGER	A Astounding Epistle of a Database Administrator And a Explorer who must Find a Car in Ancient China	2006	1	3	4.99	48	12.99	G
# 3	ADAPTATION HOLES	A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory	2006	1	7	2.99	50	18.99	NC-17
# 4	AFFAIR PREJUDICE	A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank	2006	1	5	2.99	117	26.99	G
# 5	AFRICAN EGG	A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico	2006	1	6	2.99	130	22.99	G
# 6	AGENT TRUMAN	A Intrepid Panorama of a Robot And a Boy who must Escape a Sumo Wrestler in Ancient China	2006	1	3	2.99	169	17.99	PG
# 7	AIRPLANE SIERRA	A Touching Saga of a Hunter And a Butler who must Discover a Butler in A Jet Boat	2006	1	6	4.99	62	28.99	PG-13
# 8	AIRPORT POLLOCK	A Epic Tale of a Moose And a Girl who must Confront a Monkey in Ancient India	2006	1	6	4.99	54	15.99	R
# 9	ALABAMA DEVIL	A Thoughtful Panorama of a Database Administrator And a Mad Scientist who must Outgun a Mad Scientist in A Jet Boat	2006	1	3	2.99	114	21.99	PG-13
# 10	ALADDIN CALENDAR	A Action-Packed Tale of a Man And a Lumberjack who must Reach a Feminist in Ancient China	2006	1	6	4.99	63	24.99	NC-17
# cliente_id	primeiro_nome	ultimo_nome	email	endereco_id
# 1	MARY	SMITH	MARY.SMITH@sakilacustomer.org	5
# 2	PATRICIA	JOHNSON	PATRICIA.JOHNSON@sakilacustomer.org	6
# 3	LINDA	WILLIAMS	LINDA.WILLIAMS@sakilacustomer.org	7
# 4	BARBARA	JONES	BARBARA.JONES@sakilacustomer.org	8
# 5	ELIZABETH	BROWN	ELIZABETH.BROWN@sakilacustomer.org	9
# 6	JENNIFER	DAVIS	JENNIFER.DAVIS@sakilacustomer.org	10
# 7	MARIA	MILLER	MARIA.MILLER@sakilacustomer.org	11
# 8	SUSAN	WILSON	SUSAN.WILSON@sakilacustomer.org	12
# 9	MARGARET	MOORE	MARGARET.MOORE@sakilacustomer.org	13
# 10	DOROTHY	TAYLOR	DOROTHY.TAYLOR@sakilacustomer.org	14
# aluguel_id	data_aluguel	inventario_id	cliente_id	data_devolucao
# 1	2005-05-24 22:53:30	367	130	2005-05-26 22:04:30
# 2	2005-05-24 22:54:33	1525	459	2005-05-28 19:40:33
# 3	2005-05-24 23:03:39	1711	408	2005-06-01 22:12:39
# 4	2005-05-24 23:04:41	2452	333	2005-06-03 01:43:41
# 5	2005-05-24 23:05:21	2079	222	2005-06-02 04:33:21
# 6	2005-05-24 23:08:07	2792	549	2005-05-27 01:32:07
# 7	2005-05-24 23:11:53	3995	269	2005-05-29 20:34:53
# 8	2005-05-24 23:31:46	2346	239	2005-05-27 23:33:46
# 9	2005-05-25 00:00:40	2580	126	2005-05-28 00:22:40
# 10	2005-05-25 00:02:21	1824	399	2005-05-31 22:44:21
# filme_id	titulo	categoria
# 1	ACADEMY DINOSAUR	Documentary
# 2	ACE GOLDFINGER	Horror
# 3	ADAPTATION HOLES	Documentary
# 4	AFFAIR PREJUDICE	Horror
# 5	AFRICAN EGG	Family
# 6	AGENT TRUMAN	Foreign
# 7	AIRPLANE SIERRA	Comedy
# 8	AIRPORT POLLOCK	Horror
# 9	ALABAMA DEVIL	Horror
# 10	ALADDIN CALENDAR	Sports
# 11	ALAMO VIDEOTAPE	Foreign
# 12	ALASKA PHANTOM	Music
# 13	ALI FOREVER	Horror
# 14	ALICE FANTASIA	Classics
# 15	ALIEN CENTER	Foreign
# 16	ALLEY EVOLUTION	Foreign
# 17	ALONE TRIP	Music
# 18	ALTER VICTORY	Animation
# 19	AMADEUS HOLY	Action
# 20	AMELIE HELLFIGHTERS	Music
# 21	AMERICAN CIRCUS	Action
# 22	AMISTAD MIDSUMMER	New
# 23	ANACONDA CONFESSIONS	Animation
# 24	ANALYZE HOOSIERS	Horror
# 25	ANGELS LIFE	New
# 26	ANNIE IDENTITY	Sci-Fi
# 27	ANONYMOUS HUMAN	Sports
# 28	ANTHEM LUKE	Comedy
# 29	ANTITRUST TOMATOES	Action
# 30	ANYTHING SAVANNAH	Horror
# 31	APACHE DIVINE	Family
# 32	APOCALYPSE FLAMINGOS	New
# 33	APOLLO TEEN	Drama
# 34	ARABIA DOGMA	Horror
# 35	ARACHNOPHOBIA ROLLERCOASTER	Horror
# 36	ARGONAUTS TOWN	Animation
# 37	ARIZONA BANG	Classics
# 38	ARK RIDGEMONT	Action
# 39	ARMAGEDDON LOST	Sci-Fi
# 40	ARMY FLINTSTONES	Documentary
# 41	ARSENIC INDEPENDENCE	Travel
# 42	ARTIST COLDBLOODED	Sports
# 43	ATLANTIS CAUSE	Family
# 44	ATTACKS HATE	Sci-Fi
# 45	ATTRACTION NEWTON	New
# 46	AUTUMN CROW	Games
# 47	BABY HALL	Foreign
# 48	BACKLASH UNDEFEATED	Children
# 49	BADMAN DAWN	Sci-Fi
# 50	BAKED CLEOPATRA	Family
# 51	BALLOON HOMEWARD	Music
# 52	BALLROOM MOCKINGBIRD	Foreign
# 53	BANG KWAI	Family
# 54	BANGER PINOCCHIO	Music
# 55	BARBARELLA STREETCAR	Sci-Fi
# 56	BAREFOOT MANCHURIAN	Action
# 57	BASIC EASY	Travel
# 58	BEACH HEARTBREAKERS	Documentary
# 59	BEAR GRACELAND	Children
# 60	BEAST HUNCHBACK	Classics
# 61	BEAUTY GREASE	Drama
# 62	BED HIGHBALL	Documentary
# 63	BEDAZZLED MARRIED	Family
# 64	BEETHOVEN EXORCIST	Drama
# 65	BEHAVIOR RUNAWAY	Horror
# 66	BENEATH RUSH	Children
# 67	BERETS AGENT	Action
# 68	BETRAYED REAR	Children
# 69	BEVERLY OUTLAW	Sci-Fi
# 70	BIKINI BORROWERS	Animation
# 71	BILKO ANONYMOUS	Family
# 72	BILL OTHERS	Documentary
# 73	BINGO TALENTED	Sci-Fi
# 74	BIRCH ANTITRUST	Music
# 75	BIRD INDEPENDENCE	Travel
# 76	BIRDCAGE CASPER	Music
# 77	BIRDS PERDITION	New
# 78	BLACKOUT PRIVATE	Animation
# 79	BLADE POLISH	Drama
# 80	BLANKET BEVERLY	Family
# 81	BLINDNESS GUN	Sci-Fi
# 82	BLOOD ARGONAUTS	Family
# 83	BLUES INSTINCT	Family
# 84	BOILED DARES	Travel
# 85	BONNIE HOLOCAUST	Documentary
# 86	BOOGIE AMELIE	Music
# 87	BOONDOCK BALLROOM	Travel
# 88	BORN SPINAL	Travel
# 89	BORROWERS BEDAZZLED	Animation
# 90	BOULEVARD MOB	New
# 91	BOUND CHEAPER	Classics
# 92	BOWFINGER GABLES	Horror
# 93	BRANNIGAN SUNRISE	New
# 94	BRAVEHEART HUMAN	Family
# 95	BREAKFAST GOLDFINGER	New
# 96	BREAKING HOME	New
# 97	BRIDE INTRIGUE	Action
# 98	BRIGHT ENCOUNTERS	Drama
# 99	BRINGING HYSTERICAL	Comedy
# 100	BROOKLYN DESERT	Foreign
# 101	BROTHERHOOD BLANKET	Documentary
# 102	BUBBLE GROSSE	Sports
# 103	BUCKET BROTHERHOOD	Travel
# 104	BUGSY SONG	Foreign
# 105	BULL SHAWSHANK	Action
# 106	BULWORTH COMMANDMENTS	Games
# 107	BUNCH MINDS	Drama
# 108	BUTCH PANTHER	New
# 109	BUTTERFLY CHOCOLAT	New
# 110	CABIN FLASH	Children
# 111	CADDYSHACK JEDI	Action
# 112	CALENDAR GUNFIGHT	Foreign
# 113	CALIFORNIA BIRDS	Sports
# 114	CAMELOT VACATION	Sci-Fi
# 115	CAMPUS REMEMBER	Action
# 116	CANDIDATE PERDITION	Classics
# 117	CANDLES GRAPES	Games
# 118	CANYON STOCK	Animation
# 119	CAPER MOTIONS	Comedy
# 120	CARIBBEAN LIBERTY	Sports
# 121	CAROL TEXAS	Animation
# 122	CARRIE BUNCH	Horror
# 123	CASABLANCA SUPER	Travel
# 124	CASPER DRAGONFLY	Children
# 125	CASSIDY WYOMING	Travel
# 126	CASUALTIES ENCINO	Action
# 127	CAT CONEHEADS	Comedy
# 128	CATCH AMISTAD	Foreign
# 129	CAUSE DATE	Documentary
# 130	CELEBRITY HORN	Action
# 131	CENTER DINOSAUR	Classics
# 132	CHAINSAW UPTOWN	Sci-Fi
# 133	CHAMBER ITALIAN	Music
# 134	CHAMPION FLATLINERS	Animation
# 135	CHANCE RESURRECTION	Sports
# 136	CHAPLIN LICENSE	New
# 137	CHARADE DUFFEL	Sci-Fi
# 138	CHARIOTS CONSPIRACY	Sci-Fi
# 139	CHASING FIGHT	Family
# 140	CHEAPER CLYDE	Sci-Fi
# 141	CHICAGO NORTH	Games
# 142	CHICKEN HELLFIGHTERS	Documentary
# 143	CHILL LUCK	Drama
# 144	CHINATOWN GLADIATOR	New
# 145	CHISUM BEHAVIOR	Family
# 146	CHITTY LOCK	Drama
# 147	CHOCOLAT HARRY	Family
# 148	CHOCOLATE DUCK	Foreign
# 149	CHRISTMAS MOONSHINE	Children
# 150	CIDER DESIRE	Documentary
# 151	CINCINATTI WHISPERER	Sci-Fi
# 152	CIRCUS YOUTH	Children
# 153	CITIZEN SHREK	Sci-Fi
# 154	CLASH FREDDY	Animation
# 155	CLEOPATRA DEVIL	New
# 156	CLERKS ANGELS	Documentary
# 157	CLOCKWORK PARADISE	Children
# 158	CLONES PINOCCHIO	Music
# 159	CLOSER BANG	Comedy
# 160	CLUB GRAFFITI	Animation
# 161	CLUE GRAIL	Music
# 162	CLUELESS BUCKET	Action
# 163	CLYDE THEORY	New
# 164	COAST RAINBOW	Documentary
# 165	COLDBLOODED DARLING	Sci-Fi
# 166	COLOR PHILADELPHIA	Classics
# 167	COMA HEAD	Travel
# 168	COMANCHEROS ENEMY	Children
# 169	COMFORTS RUSH	Travel
# 170	COMMAND DARLING	Foreign
# 171	COMMANDMENTS EXPRESS	Horror
# 172	CONEHEADS SMOOCHY	Drama
# 173	CONFESSIONS MAGUIRE	Drama
# 174	CONFIDENTIAL INTERVIEW	Music
# 175	CONFUSED CANDLES	Family
# 176	CONGENIALITY QUEST	Sports
# 177	CONNECTICUT TRAMP	Sci-Fi
# 178	CONNECTION MICROCOSMOS	Comedy
# 179	CONQUERER NUTS	Drama
# 180	CONSPIRACY SPIRIT	Classics
# 181	CONTACT ANONYMOUS	Travel
# 182	CONTROL ANTHEM	Comedy
# 183	CONVERSATION DOWNHILL	Family
# 184	CORE SUIT	Classics
# 185	COWBOY DOOM	Foreign
# 186	CRAFT OUTFIELD	Drama
# 187	CRANES RESERVOIR	Sports
# 188	CRAZY HOME	Comedy
# 189	CREATURES SHAKESPEARE	Games
# 190	CREEPERS KANE	Classics
# 191	CROOKED FROGMEN	Children
# 192	CROSSING DIVORCE	Foreign
# 193	CROSSROADS CASUALTIES	Animation
# 194	CROW GREASE	Action
# 195	CROWDS TELEMARK	Sci-Fi
# 196	CRUELTY UNFORGIVEN	Classics
# 197	CRUSADE HONEY	Sports
# 198	CRYSTAL BREAKING	Foreign
# 199	CUPBOARD SINNERS	Documentary
# 200	CURTAIN VIDEOTAPE	Games
# 201	CYCLONE FAMILY	Foreign
# 202	DADDY PITTSBURGH	Comedy
# 203	DAISY MENAGERIE	Sci-Fi
# 204	DALMATIONS SWEDEN	Drama
# 205	DANCES NONE	Action
# 206	DANCING FEVER	Documentary
# 207	DANGEROUS UPTOWN	Foreign
# 208	DARES PLUTO	Animation
# 209	DARKNESS WAR	Drama
# 210	DARKO DORADO	Action
# 211	DARLING BREAKING	Games
# 212	DARN FORRESTER	Action
# 213	DATE SPEED	Family
# 214	DAUGHTER MADIGAN	Children
# 215	DAWN POND	Games
# 216	DAY UNFAITHFUL	New
# 217	DAZED PUNK	Games
# 218	DECEIVER BETRAYED	Drama
# 219	DEEP CRUSADE	Documentary
# 220	DEER VIRGINIAN	Music
# 221	DELIVERANCE MULHOLLAND	Documentary
# 222	DESERT POSEIDON	Horror
# 223	DESIRE ALIEN	Animation
# 224	DESPERATE TRAINSPOTTING	Travel
# 225	DESTINATION JERK	Drama
# 226	DESTINY SATURDAY	New
# 227	DETAILS PACKER	Games
# 228	DETECTIVE VISION	Classics
# 229	DEVIL DESIRE	Action
# 230	DIARY PANIC	Drama
# 231	DINOSAUR SECRETARY	Family
# 232	DIRTY ACE	Games
# 233	DISCIPLE MOTHER	Travel
# 234	DISTURBING SCARFACE	Sci-Fi
# 235	DIVIDE MONSTER	Sci-Fi
# 236	DIVINE RESURRECTION	Games
# 237	DIVORCE SHINING	Sports
# 238	DOCTOR GRAIL	Children
# 239	DOGMA FAMILY	Animation
# 240	DOLLS RAGE	Sci-Fi
# 241	DONNIE ALLEY	Animation
# 242	DOOM DANCING	Comedy
# 243	DOORS PRESIDENT	Animation
# 244	DORADO NOTTING	Music
# 245	DOUBLE WRATH	Animation
# 246	DOUBTFIRE LABYRINTH	Foreign
# 247	DOWNHILL ENOUGH	Comedy
# 248	DOZEN LION	Documentary
# 249	DRACULA CRYSTAL	Classics
# 250	DRAGON SQUAD	Action
# 251	DRAGONFLY STRANGERS	New
# 252	DREAM PICKUP	Action
# 253	DRIFTER COMMANDMENTS	Action
# 254	DRIVER ANNIE	Sports
# 255	DRIVING POLISH	Music
# 256	DROP WATERFRONT	Sports
# 257	DRUMLINE CYCLONE	Travel
# 258	DRUMS DYNAMITE	Horror
# 259	DUCK RACER	Animation
# 260	DUDE BLINDNESS	Sports
# 261	DUFFEL APOCALYPSE	Documentary
# 262	DUMBO LUST	Family
# 263	DURHAM PANKY	Sports
# 264	DWARFS ALTER	Games
# 265	DYING MAKER	Comedy
# 266	DYNAMITE TARZAN	Classics
# 267	EAGLES PANKY	New
# 268	EARLY HOME	Animation
# 269	EARRING INSTINCT	Family
# 270	EARTH VISION	New
# 271	EASY GLADIATOR	Action
# 272	EDGE KISSING	Drama
# 273	EFFECT GLADIATOR	Family
# 274	EGG IGBY	Documentary
# 275	EGYPT TENENBAUMS	Horror
# 276	ELEMENT FREDDY	Comedy
# 277	ELEPHANT TROJAN	Horror
# 278	ELF MURDER	Music
# 279	ELIZABETH SHANE	Sports
# 280	EMPIRE MALKOVICH	Children
# 281	ENCINO ELF	Games
# 282	ENCOUNTERS CURTAIN	Drama
# 283	ENDING CROWDS	New
# 284	ENEMY ODDS	Music
# 285	ENGLISH BULWORTH	Sci-Fi
# 286	ENOUGH RAGING	Travel
# 287	ENTRAPMENT SATISFACTION	Action
# 288	ESCAPE METROPOLIS	Travel
# 289	EVE RESURRECTION	New
# 290	EVERYONE CRAFT	Foreign
# 291	EVOLUTION ALTER	Sports
# 292	EXCITEMENT EVE	Action
# 293	EXORCIST STING	Sports
# 294	EXPECATIONS NATURAL	Travel
# 295	EXPENDABLE STALLION	Documentary
# 296	EXPRESS LONELY	Sci-Fi
# 297	EXTRAORDINARY CONQUERER	Classics
# 298	EYES DRIVING	Sci-Fi
# 299	FACTORY DRAGON	Travel
# 300	FALCON VOLUME	Animation
# 301	FAMILY SWEET	Horror
# 302	FANTASIA PARK	Games
# 303	FANTASY TROOPERS	Action
# 304	FARGO GANDHI	Children
# 305	FATAL HAUNTED	New
# 306	FEATHERS METAL	Games
# 307	FELLOWSHIP AUTUMN	Travel
# 308	FERRIS MOTHER	Comedy
# 309	FEUD FROGMEN	Family
# 310	FEVER EMPIRE	Games
# 311	FICTION CHRISTMAS	Foreign
# 312	FIDDLER LOST	Sci-Fi
# 313	FIDELITY DEVIL	Horror
# 314	FIGHT JAWBREAKER	Animation
# 315	FINDING ANACONDA	Family
# 316	FIRE WOLVES	Games
# 317	FIREBALL PHILADELPHIA	Comedy
# 318	FIREHOUSE VIETNAM	Action
# 319	FISH OPUS	Sci-Fi
# 320	FLAMINGOS CONNECTICUT	New
# 321	FLASH WARS	New
# 322	FLATLINERS KILLER	Sports
# 323	FLIGHT LIES	Sports
# 324	FLINTSTONES HAPPINESS	Comedy
# 325	FLOATS GARDEN	Animation
# 326	FLYING HOOK	Animation
# 327	FOOL MOCKINGBIRD	Action
# 328	FOREVER CANDIDATE	Children
# 329	FORREST SONS	Action
# 330	FORRESTER COMANCHEROS	Animation
# 331	FORWARD TEMPLE	Games
# 332	FRANKENSTEIN STRANGER	Comedy
# 333	FREAKY POCUS	Music
# 334	FREDDY STORM	Horror
# 335	FREEDOM CLEOPATRA	Comedy
# 336	FRENCH HOLIDAY	Documentary
# 337	FRIDA SLIPPER	Foreign
# 338	FRISCO FORREST	Sci-Fi
# 339	FROGMEN BREAKING	Travel
# 340	FRONTIER CABIN	New
# 341	FROST HEAD	Classics
# 342	FUGITIVE MAGUIRE	Travel
# 343	FULL FLATLINERS	Children
# 344	FURY MURDER	Children
# 345	GABLES METROPOLIS	Family
# 346	GALAXY SWEETHEARTS	Classics
# 347	GAMES BOWFINGER	Travel
# 348	GANDHI KWAI	Family
# 349	GANGS PRIDE	Animation
# 350	GARDEN ISLAND	Sci-Fi
# 351	GASLIGHT CRUSADE	Horror
# 352	GATHERING CALENDAR	Games
# 353	GENTLEMEN STAGE	Foreign
# 354	GHOST GROUNDHOG	Children
# 355	GHOSTBUSTERS ELF	Animation
# 356	GIANT TROOPERS	Children
# 357	GILBERT PELICAN	Classics
# 358	GILMORE BOILED	Classics
# 359	GLADIATOR WESTWARD	Family
# 360	GLASS DYING	Action
# 361	GLEAMING JAWBREAKER	Sports
# 362	GLORY TRACY	Games
# 363	GO PURPLE	Music
# 364	GODFATHER DIARY	New
# 365	GOLD RIVER	Comedy
# 366	GOLDFINGER SENSIBILITY	Drama
# 367	GOLDMINE TYCOON	Sci-Fi
# 368	GONE TROUBLE	Drama
# 369	GOODFELLAS SALUTE	Sci-Fi
# 370	GORGEOUS BINGO	Children
# 371	GOSFORD DONNIE	Action
# 372	GRACELAND DYNAMITE	Sports
# 373	GRADUATE LORD	Children
# 374	GRAFFITI LOVE	Sci-Fi
# 375	GRAIL FRANKENSTEIN	Action
# 376	GRAPES FURY	Foreign
# 377	GREASE YOUTH	Family
# 378	GREATEST NORTH	Music
# 379	GREEDY ROOTS	Drama
# 380	GREEK EVERYONE	Foreign
# 381	GRINCH MASSAGE	Games
# 382	GRIT CLOCKWORK	Games
# 383	GROOVE FICTION	Sports
# 384	GROSSE WONDERFUL	Music
# 385	GROUNDHOG UNCUT	Comedy
# 386	GUMP DATE	Travel
# 387	GUN BONNIE	Games
# 388	GUNFIGHT MOON	Comedy
# 389	GUNFIGHTER MUSSOLINI	Sports
# 390	GUYS FALCON	Sci-Fi
# 391	HALF OUTFIELD	Family
# 392	HALL CASSIDY	Children
# 393	HALLOWEEN NUTS	Documentary
# 394	HAMLET WISDOM	Sci-Fi
# 395	HANDICAP BOONDOCK	Action
# 396	HANGING DEEP	Drama
# 397	HANKY OCTOBER	Sci-Fi
# 398	HANOVER GALAXY	Music
# 399	HAPPINESS UNITED	Foreign
# 400	HARDLY ROBBERS	Documentary
# 401	HAROLD FRENCH	Drama
# 402	HARPER DYING	Animation
# 403	HARRY IDAHO	Drama
# 404	HATE HANDICAP	Comedy
# 405	HAUNTED ANTITRUST	Travel
# 406	HAUNTING PIANIST	Games
# 407	HAWK CHILL	Documentary
# 408	HEAD STRANGER	Games
# 409	HEARTBREAKERS BRIGHT	Children
# 410	HEAVEN FREEDOM	Comedy
# 411	HEAVENLY GUN	Music
# 412	HEAVYWEIGHTS BEAST	Documentary
# 413	HEDWIG ALTER	Comedy
# 414	HELLFIGHTERS SIERRA	Foreign
# 415	HIGH ENCINO	Horror
# 416	HIGHBALL POTTER	Foreign
# 417	HILLS NEIGHBORS	Action
# 418	HOBBIT ALIEN	Drama
# 419	HOCUS FRIDA	Family
# 420	HOLES BRANNIGAN	Sports
# 421	HOLIDAY GAMES	Foreign
# 422	HOLLOW JEOPARDY	Sci-Fi
# 423	HOLLYWOOD ANONYMOUS	Children
# 424	HOLOCAUST HIGHBALL	Children
# 425	HOLY TADPOLE	Classics
# 426	HOME PITY	Music
# 427	HOMEWARD CIDER	Documentary
# 428	HOMICIDE PEACH	Family
# 429	HONEY TIES	Sports
# 430	HOOK CHARIOTS	Animation
# 431	HOOSIERS BIRDCAGE	Foreign
# 432	HOPE TOOTSIE	Classics
# 433	HORN WORKING	Animation
# 434	HORROR REIGN	Travel
# 435	HOTEL HAPPINESS	Foreign
# 436	HOURS RAGE	New
# 437	HOUSE DYNAMITE	Family
# 438	HUMAN GRAFFITI	Games
# 439	HUNCHBACK IMPOSSIBLE	Drama
# 440	HUNGER ROOF	Foreign
# 441	HUNTER ALTER	Documentary
# 442	HUNTING MUSKETEERS	Family
# 443	HURRICANE AFFAIR	Comedy
# 444	HUSTLER PARTY	Comedy
# 445	HYDE DOCTOR	Classics
# 446	HYSTERICAL GRAIL	Sports
# 447	ICE CROSSING	Games
# 448	IDAHO LOVE	New
# 449	IDENTITY LOVER	Sci-Fi
# 450	IDOLS SNATCHERS	Children
# 451	IGBY MAKER	Travel
# 452	ILLUSION AMELIE	Foreign
# 453	IMAGE PRINCESS	Sports
# 454	IMPACT ALADDIN	Music
# 455	IMPOSSIBLE PREJUDICE	Foreign
# 456	INCH JET	Animation
# 457	INDEPENDENCE HOTEL	Documentary
# 458	INDIAN LOVE	Family
# 459	INFORMER DOUBLE	Foreign
# 460	INNOCENT USUAL	Foreign
# 461	INSECTS STONE	Animation
# 462	INSIDER ARIZONA	Music
# 463	INSTINCT AIRPORT	Sports
# 464	INTENTIONS EMPIRE	Animation
# 465	INTERVIEW LIAISONS	New
# 466	INTOLERABLE INTENTIONS	Documentary
# 467	INTRIGUE WORST	Foreign
# 468	INVASION CYCLONE	Children
# 469	IRON MOON	Classics
# 470	ISHTAR ROCKETEER	Animation
# 471	ISLAND EXORCIST	Classics
# 472	ITALIAN AFRICAN	Travel
# 473	JACKET FRISCO	Drama
# 474	JADE BUNCH	Sports
# 475	JAPANESE RUN	Horror
# 476	JASON TRAP	Family
# 477	JAWBREAKER BROOKLYN	Music
# 478	JAWS HARRY	Comedy
# 479	JEDI BENEATH	Family
# 480	JEEPERS WEDDING	Classics
# 481	JEKYLL FROGMEN	New
# 482	JEOPARDY ENCINO	Classics
# 483	JERICHO MULAN	Games
# 484	JERK PAYCHECK	Classics
# 485	JERSEY SASSY	Children
# 486	JET NEIGHBORS	Foreign
# 487	JINGLE SAGEBRUSH	Classics
# 488	JOON NORTHWEST	Sports
# 489	JUGGLER HARDLY	Animation
# 490	JUMANJI BLADE	New
# 491	JUMPING WRATH	Children
# 492	JUNGLE CLOSER	New
# 493	KANE EXORCIST	Foreign
# 494	KARATE MOON	Horror
# 495	KENTUCKIAN GIANT	Horror
# 496	KICK SAVANNAH	Travel
# 497	KILL BROTHERHOOD	Documentary
# 498	KILLER INNOCENT	Family
# 499	KING EVOLUTION	Family
# 500	KISS GLORY	Foreign
# 501	KISSING DOLLS	Action
# 502	KNOCK WARLOCK	Comedy
# 503	KRAMER CHOCOLATE	Sports
# 504	KWAI HOMEWARD	Drama
# 505	LABYRINTH LEAGUE	Children
# 506	LADY STAGE	Horror
# 507	LADYBUGS ARMAGEDDON	Games
# 508	LAMBS CINCINATTI	Games
# 509	LANGUAGE COWBOY	Children
# 510	LAWLESS VISION	Animation
# 511	LAWRENCE LOVE	Action
# 512	LEAGUE HELLFIGHTERS	Classics
# 513	LEATHERNECKS DWARFS	Travel
# 514	LEBOWSKI SOLDIERS	Drama
# 515	LEGALLY SECRETARY	Children
# 516	LEGEND JEDI	Music
# 517	LESSON CLEOPATRA	Sports
# 518	LIAISONS SWEET	Travel
# 519	LIBERTY MAGNIFICENT	Sports
# 520	LICENSE WEEKEND	Sci-Fi
# 521	LIES TREATMENT	Drama
# 522	LIFE TWISTED	Comedy
# 523	LIGHTS DEER	Classics
# 524	LION UNCUT	Comedy
# 525	LOATHING LEGALLY	Classics
# 526	LOCK REAR	Travel
# 527	LOLA AGENT	Horror
# 528	LOLITA WORLD	Family
# 529	LONELY ELEPHANT	Comedy
# 530	LORD ARIZONA	Action
# 531	LOSE INCH	Foreign
# 532	LOSER HUSTLER	Sports
# 533	LOST BIRD	Foreign
# 534	LOUISIANA HARRY	Family
# 535	LOVE SUICIDES	Horror
# 536	LOVELY JINGLE	Classics
# 537	LOVER TRUMAN	Classics
# 538	LOVERBOY ATTACKS	New
# 539	LUCK OPUS	Drama
# 540	LUCKY FLYING	Music
# 541	LUKE MUMMY	Animation
# 542	LUST LOCK	Action
# 543	MADIGAN DORADO	Travel
# 544	MADISON TRAP	Documentary
# 545	MADNESS ATTACKS	Foreign
# 546	MADRE GABLES	Games
# 547	MAGIC MALLRATS	Children
# 548	MAGNIFICENT CHITTY	Classics
# 549	MAGNOLIA FORRESTER	Action
# 550	MAGUIRE APACHE	Family
# 551	MAIDEN HOME	New
# 552	MAJESTIC FLOATS	Documentary
# 553	MAKER GABLES	Children
# 554	MALKOVICH PET	Classics
# 555	MALLRATS UNITED	Comedy
# 556	MALTESE HOPE	Games
# 557	MANCHURIAN CURTAIN	Family
# 558	MANNEQUIN WORST	New
# 559	MARRIED GO	Sci-Fi
# 560	MARS ROMAN	Games
# 561	MASK PEACH	New
# 562	MASKED BUBBLE	Music
# 563	MASSACRE USUAL	Games
# 564	MASSAGE IMAGE	Animation
# 565	MATRIX SNOWMAN	Foreign
# 566	MAUDE MOD	Foreign
# 567	MEET CHOCOLATE	Foreign
# 568	MEMENTO ZOOLANDER	Comedy
# 569	MENAGERIE RUSHMORE	Animation
# 570	MERMAID INSECTS	Sports
# 571	METAL ARMAGEDDON	Documentary
# 572	METROPOLIS COMA	Sci-Fi
# 573	MICROCOSMOS PARADISE	Children
# 574	MIDNIGHT WESTWARD	Action
# 575	MIDSUMMER GROUNDHOG	Documentary
# 576	MIGHTY LUCK	Documentary
# 577	MILE MULAN	Sports
# 578	MILLION ACE	Classics
# 579	MINDS TRUMAN	Action
# 580	MINE TITANS	New
# 581	MINORITY KISS	Music
# 582	MIRACLE VIRTUAL	Animation
# 583	MISSION ZOOLANDER	Animation
# 584	MIXED DOORS	Foreign
# 585	MOB DUFFEL	Drama
# 586	MOCKINGBIRD HOLLYWOOD	Action
# 587	MOD SECRETARY	Documentary
# 588	MODEL FISH	Children
# 589	MODERN DORADO	Documentary
# 590	MONEY HAROLD	New
# 591	MONSOON CAUSE	Games
# 592	MONSTER SPARTACUS	Music
# 593	MONTEREY LABYRINTH	Horror
# 594	MONTEZUMA COMMAND	Action
# 595	MOON BUNCH	Foreign
# 596	MOONSHINE CABIN	Games
# 597	MOONWALKER FOOL	Games
# 598	MOSQUITO ARMAGEDDON	Sports
# 599	MOTHER OLEANDER	Sports
# 600	MOTIONS DETAILS	Horror
# 601	MOULIN WAKE	Travel
# 602	MOURNING PURPLE	Sci-Fi
# 603	MOVIE SHAKESPEARE	Family
# 604	MULAN MOON	Comedy
# 605	MULHOLLAND BEAST	Foreign
# 606	MUMMY CREATURES	Sports
# 607	MUPPET MILE	Foreign
# 608	MURDER ANTITRUST	Children
# 609	MUSCLE BRIGHT	Travel
# 610	MUSIC BOONDOCK	Family
# 611	MUSKETEERS WAIT	Classics
# 612	MUSSOLINI SPOILERS	Sports
# 613	MYSTIC TRUMAN	Comedy
# 614	NAME DETECTIVE	Games
# 615	NASH CHOCOLAT	Animation
# 616	NATIONAL STORY	Documentary
# 617	NATURAL STOCK	Family
# 618	NECKLACE OUTBREAK	Drama
# 619	NEIGHBORS CHARADE	Sports
# 620	NEMO CAMPUS	Sci-Fi
# 621	NETWORK PEAK	Family
# 622	NEWSIES STORY	Documentary
# 623	NEWTON LABYRINTH	Foreign
# 624	NIGHTMARE CHILL	Games
# 625	NONE SPIKING	Sci-Fi
# 626	NOON PAPI	Children
# 627	NORTH TEQUILA	Documentary
# 628	NORTHWEST POLISH	Sports
# 629	NOTORIOUS REUNION	Documentary
# 630	NOTTING SPEAKEASY	Drama
# 631	NOVOCAINE FLIGHT	Sports
# 632	NUTS TIES	New
# 633	OCTOBER SUBMARINE	Classics
# 634	ODDS BOOGIE	Family
# 635	OKLAHOMA JUMANJI	New
# 636	OLEANDER CLUE	Music
# 637	OPEN AFRICAN	Sci-Fi
# 638	OPERATION OPERATION	Comedy
# 639	OPPOSITE NECKLACE	Family
# 640	OPUS ICE	Foreign
# 641	ORANGE GRAPES	Foreign
# 642	ORDER BETRAYED	Travel
# 643	ORIENT CLOSER	Drama
# 644	OSCAR GOLD	Animation
# 645	OTHERS SOUP	Travel
# 646	OUTBREAK DIVINE	Games
# 647	OUTFIELD MASSACRE	Music
# 648	OUTLAW HANKY	Travel
# 649	OZ LIAISONS	Animation
# 650	PACIFIC AMISTAD	Documentary
# 651	PACKER MADIGAN	Animation
# 652	PAJAMA JAWBREAKER	Classics
# 653	PANIC CLUB	Horror
# 654	PANKY SUBMARINE	Games
# 655	PANTHER REDS	Sci-Fi
# 656	PAPI NECKLACE	Travel
# 657	PARADISE SABRINA	Comedy
# 658	PARIS WEEKEND	Horror
# 659	PARK CITIZEN	Action
# 660	PARTY KNOCK	Comedy
# 661	PAST SUICIDES	Foreign
# 662	PATHS CONTROL	Drama
# 663	PATIENT SISTER	Classics
# 664	PATRIOT ROMAN	Action
# 665	PATTON INTERVIEW	Horror
# 666	PAYCHECK WAIT	Drama
# 667	PEACH INNOCENT	Sports
# 668	PEAK FOREVER	Sports
# 669	PEARL DESTINY	Foreign
# 670	PELICAN COMFORTS	Documentary
# 671	PERDITION FARGO	Sports
# 672	PERFECT GROOVE	Comedy
# 673	PERSONAL LADYBUGS	Music
# 674	PET HAUNTING	Foreign
# 675	PHANTOM GLORY	New
# 676	PHILADELPHIA WIFE	Sports
# 677	PIANIST OUTFIELD	New
# 678	PICKUP DRIVING	Sports
# 679	PILOT HOOSIERS	Family
# 680	PINOCCHIO SIMON	Comedy
# 681	PIRATES ROXANNE	Sports
# 682	PITTSBURGH HUNCHBACK	Family
# 683	PITY BOUND	Drama
# 684	PIZZA JUMANJI	Games
# 685	PLATOON INSTINCT	New
# 686	PLUTO OLEANDER	New
# 687	POCUS PULP	Documentary
# 688	POLISH BROOKLYN	Children
# 689	POLLOCK DELIVERANCE	Foreign
# 690	POND SEATTLE	Animation
# 691	POSEIDON FOREVER	Sports
# 692	POTLUCK MIXED	Animation
# 693	POTTER CONNECTICUT	Animation
# 694	PREJUDICE OLEANDER	Classics
# 695	PRESIDENT BANG	Family
# 696	PRIDE ALAMO	Animation
# 697	PRIMARY GLASS	Action
# 698	PRINCESS GIANT	Documentary
# 699	PRIVATE DROP	Games
# 700	PRIX UNDEFEATED	Family
# 701	PSYCHO SHRUNK	Games
# 702	PULP BEVERLY	Horror
# 703	PUNK DIVORCE	Animation
# 704	PURE RUNNER	Comedy
# 705	PURPLE MOVIE	Foreign
# 706	QUEEN LUKE	Drama
# 707	QUEST MUSSOLINI	Action
# 708	QUILLS BULL	Documentary
# 709	RACER EGG	Drama
# 710	RAGE GAMES	Family
# 711	RAGING AIRPLANE	Sci-Fi
# 712	RAIDERS ANTITRUST	Documentary
# 713	RAINBOW SHOCK	Documentary
# 714	RANDOM GO	Sci-Fi
# 715	RANGE MOONWALKER	Family
# 716	REAP UNFAITHFUL	Horror
# 717	REAR TRADING	Action
# 718	REBEL AIRPORT	Music
# 719	RECORDS ZORRO	Sports
# 720	REDEMPTION COMFORTS	New
# 721	REDS POCUS	Music
# 722	REEF SALUTE	Horror
# 723	REIGN GENTLEMEN	Sci-Fi
# 724	REMEMBER DIARY	Family
# 725	REQUIEM TYCOON	Classics
# 726	RESERVOIR ADAPTATION	Foreign
# 727	RESURRECTION SILVERADO	Family
# 728	REUNION WITCHES	Drama
# 729	RIDER CADDYSHACK	Sports
# 730	RIDGEMONT SUBMARINE	New
# 731	RIGHT CRANES	Classics
# 732	RINGS HEARTBREAKERS	Action
# 733	RIVER OUTLAW	Sports
# 734	ROAD ROXANNE	Documentary
# 735	ROBBERS JOON	Children
# 736	ROBBERY BRIGHT	Family
# 737	ROCK INSTINCT	Horror
# 738	ROCKETEER MOTHER	Foreign
# 739	ROCKY WAR	Drama
# 740	ROLLERCOASTER BRINGING	Horror
# 741	ROMAN PUNK	Music
# 742	ROOF CHAMPION	Games
# 743	ROOM ROMAN	Animation
# 744	ROOTS REMEMBER	Classics
# 745	ROSES TREASURE	Sports
# 746	ROUGE SQUAD	Games
# 747	ROXANNE REBEL	Games
# 748	RUGRATS SHAKESPEARE	Action
# 749	RULES HUMAN	Horror
# 750	RUN PACIFIC	New
# 751	RUNAWAY TENENBAUMS	New
# 752	RUNNER MADIGAN	Music
# 753	RUSH GOODFELLAS	Family
# 754	RUSHMORE MERMAID	Comedy
# 755	SABRINA MIDNIGHT	Children
# 756	SADDLE ANTITRUST	Comedy
# 757	SAGEBRUSH CLUELESS	Documentary
# 758	SAINTS BRIDE	Drama
# 759	SALUTE APOLLO	New
# 760	SAMURAI LION	New
# 761	SANTA PARIS	Children
# 762	SASSY PACKER	Games
# 763	SATISFACTION CONFIDENTIAL	Sports
# 764	SATURDAY LAMBS	Sports
# 765	SATURN NAME	Comedy
# 766	SAVANNAH TOWN	Drama
# 767	SCALAWAG DUCK	Music
# 768	SCARFACE BANG	Children
# 769	SCHOOL JACKET	Foreign
# 770	SCISSORHANDS SLUMS	Foreign
# 771	SCORPION APOLLO	Drama
# 772	SEA VIRGIN	Drama
# 773	SEABISCUIT PUNK	Sports
# 774	SEARCHERS WAIT	Comedy
# 775	SEATTLE EXPECATIONS	Drama
# 776	SECRET GROUNDHOG	Documentary
# 777	SECRETARY ROUGE	Sports
# 778	SECRETS PARADISE	Family
# 779	SENSE GREEK	Sports
# 780	SENSIBILITY REAR	Family
# 781	SEVEN SWARM	Games
# 782	SHAKESPEARE SADDLE	Sports
# 783	SHANE DARKNESS	Travel
# 784	SHANGHAI TYCOON	Travel
# 785	SHAWSHANK BUBBLE	Travel
# 786	SHEPHERD MIDSUMMER	Children
# 787	SHINING ROSES	Travel
# 788	SHIP WONDERLAND	Documentary
# 789	SHOCK CABIN	Foreign
# 790	SHOOTIST SUPERFLY	Drama
# 791	SHOW LORD	Documentary
# 792	SHREK LICENSE	Foreign
# 793	SHRUNK DIVINE	Action
# 794	SIDE ARK	Action
# 795	SIEGE MADRE	Family
# 796	SIERRA DIVIDE	Sports
# 797	SILENCE KANE	Music
# 798	SILVERADO GOLDFINGER	Sci-Fi
# 799	SIMON NORTH	Horror
# 800	SINNERS ATLANTIS	Horror
# 801	SISTER FREDDY	Children
# 802	SKY MIRACLE	Action
# 803	SLACKER LIAISONS	Drama
# 804	SLEEPING SUSPECTS	Horror
# 805	SLEEPLESS MONSOON	Animation
# 806	SLEEPY JAPANESE	New
# 807	SLEUTH ORIENT	Games
# 808	SLING LUKE	Classics
# 809	SLIPPER FIDELITY	Sports
# 810	SLUMS DUCK	Family
# 811	SMILE EARRING	Travel
# 812	SMOKING BARBARELLA	Documentary
# 813	SMOOCHY CONTROL	Sports
# 814	SNATCH SLIPPER	Comedy
# 815	SNATCHERS MONTEZUMA	Classics
# 816	SNOWMAN ROLLERCOASTER	Animation
# 817	SOLDIERS EVOLUTION	Sci-Fi
# 818	SOMETHING DUCK	Drama
# 819	SONG HEDWIG	Music
# 820	SONS INTERVIEW	Animation
# 821	SORORITY QUEEN	Foreign
# 822	SOUP WISDOM	Family
# 823	SOUTH WAIT	Action
# 824	SPARTACUS CHEAPER	Family
# 825	SPEAKEASY DATE	Action
# 826	SPEED SUIT	Travel
# 827	SPICE SORORITY	Drama
# 828	SPIKING ELEMENT	Classics
# 829	SPINAL ROCKY	Family
# 830	SPIRIT FLINTSTONES	Horror
# 831	SPIRITED CASUALTIES	Sci-Fi
# 832	SPLASH GUMP	Family
# 833	SPLENDOR PATTON	Children
# 834	SPOILERS HELLFIGHTERS	Documentary
# 835	SPY MILE	Games
# 836	SQUAD FISH	Sports
# 837	STAGE WORLD	Comedy
# 838	STAGECOACH ARMAGEDDON	Action
# 839	STALLION SUNDANCE	Sci-Fi
# 840	STAMPEDE DISTURBING	Games
# 841	STAR OPERATION	Sports
# 842	STATE WASTELAND	Games
# 843	STEEL SANTA	Classics
# 844	STEERS ARMAGEDDON	Sports
# 845	STEPMOM DREAM	Foreign
# 846	STING PERSONAL	New
# 847	STOCK GLASS	New
# 848	STONE FIRE	Travel
# 849	STORM HAPPINESS	Animation
# 850	STORY SIDE	Action
# 851	STRAIGHT HOURS	Sports
# 852	STRANGELOVE DESIRE	Children
# 853	STRANGER STRANGERS	Children
# 854	STRANGERS GRAFFITI	Horror
# 855	STREAK RIDGEMONT	Documentary
# 856	STREETCAR INTENTIONS	Horror
# 857	STRICTLY SCARFACE	Comedy
# 858	SUBMARINE BED	Comedy
# 859	SUGAR WONKA	Animation
# 860	SUICIDES SILENCE	Sci-Fi
# 861	SUIT WALLS	Games
# 862	SUMMER SCARFACE	Classics
# 863	SUN CONFESSIONS	Sci-Fi
# 864	SUNDANCE INVASION	Children
# 865	SUNRISE LEAGUE	Animation
# 866	SUNSET RACER	Family
# 867	SUPER WYOMING	Family
# 868	SUPERFLY TRIP	Travel
# 869	SUSPECTS QUILLS	Action
# 870	SWARM GOLD	Horror
# 871	SWEDEN SHINING	Comedy
# 872	SWEET BROTHERHOOD	Travel
# 873	SWEETHEARTS SUSPECTS	Children
# 874	TADPOLE PARK	Classics
# 875	TALENTED HOMICIDE	Sports
# 876	TARZAN VIDEOTAPE	Horror
# 877	TAXI KICK	Music
# 878	TEEN APOLLO	Travel
# 879	TELEGRAPH VOYAGE	Music
# 880	TELEMARK HEARTBREAKERS	Animation
# 881	TEMPLE ATTRACTION	Horror
# 882	TENENBAUMS COMMAND	Drama
# 883	TEQUILA PAST	Children
# 884	TERMINATOR CLUB	Music
# 885	TEXAS WATCH	Horror
# 886	THEORY MERMAID	Animation
# 887	THIEF PELICAN	Animation
# 888	THIN SAGEBRUSH	Documentary
# 889	TIES HUNGER	Children
# 890	TIGHTS DAWN	Sports
# 891	TIMBERLAND SKY	Classics
# 892	TITANIC BOONDOCK	Animation
# 893	TITANS JERK	Sci-Fi
# 894	TOMATOES HELLFIGHTERS	Travel
# 895	TOMORROW HUSTLER	Classics
# 896	TOOTSIE PILOT	Children
# 897	TORQUE BOUND	Drama
# 898	TOURIST PELICAN	Sports
# 899	TOWERS HURRICANE	Classics
# 900	TOWN ARK	Foreign
# 901	TRACY CIDER	Animation
# 902	TRADING PINOCCHIO	Sports
# 903	TRAFFIC HOBBIT	Travel
# 904	TRAIN BUNCH	Horror
# 905	TRAINSPOTTING STRANGERS	Comedy
# 906	TRAMP OTHERS	Comedy
# 907	TRANSLATION SUMMER	Drama
# 908	TRAP GUYS	Foreign
# 909	TREASURE COMMAND	Horror
# 910	TREATMENT JEKYLL	Drama
# 911	TRIP NEWTON	Action
# 912	TROJAN TOMORROW	Sci-Fi
# 913	TROOPERS METAL	New
# 914	TROUBLE DATE	Travel
# 915	TRUMAN CRAZY	Action
# 916	TURN STAR	Animation
# 917	TUXEDO MILE	Sports
# 918	TWISTED PIRATES	Children
# 919	TYCOON GATHERING	Games
# 920	UNBREAKABLE KARATE	New
# 921	UNCUT SUICIDES	Music
# 922	UNDEFEATED DALMATIONS	Horror
# 923	UNFAITHFUL KILL	Drama
# 924	UNFORGIVEN ZOOLANDER	Sci-Fi
# 925	UNITED PILOT	Documentary
# 926	UNTOUCHABLES SUNRISE	Documentary
# 927	UPRISING UPTOWN	Action
# 928	UPTOWN YOUNG	Children
# 929	USUAL UNTOUCHABLES	Foreign
# 930	VACATION BOONDOCK	Sci-Fi
# 931	VALENTINE VANISHING	Travel
# 932	VALLEY PACKER	Comedy
# 933	VAMPIRE WHALE	New
# 934	VANILLA DAY	Games
# 935	VANISHED GARDEN	New
# 936	VANISHING ROCKY	Music
# 937	VARSITY TRIP	New
# 938	VELVET TERMINATOR	Comedy
# 939	VERTIGO NORTHWEST	Comedy
# 940	VICTORY ACADEMY	Sports
# 941	VIDEOTAPE ARSENIC	Games
# 942	VIETNAM SMOOCHY	Drama
# 943	VILLAIN DESPERATE	Documentary
# 944	VIRGIN DAISY	Drama
# 945	VIRGINIAN PLUTO	Documentary
# 946	VIRTUAL SPOILERS	Family
# 947	VISION TORQUE	Foreign
# 948	VOICE PEACH	New
# 949	VOLCANO TEXAS	Games
# 950	VOLUME HOUSE	Classics
# 951	VOYAGE LEGALLY	Classics
# 952	WAGON JAWS	Documentary
# 953	WAIT CIDER	Animation
# 954	WAKE JAWS	New
# 955	WALLS ARTIST	Children
# 956	WANDA CHAMBER	Games
# 957	WAR NOTTING	Foreign
# 958	WARDROBE PHANTOM	Drama
# 959	WARLOCK WEREWOLF	Children
# 960	WARS PLUTO	Documentary
# 961	WASH HEAVENLY	Foreign
# 962	WASTELAND DIVINE	Classics
# 963	WATCH TRACY	Animation
# 964	WATERFRONT DELIVERANCE	Action
# 965	WATERSHIP FRONTIER	Horror
# 966	WEDDING APOLLO	Documentary
# 967	WEEKEND PERSONAL	Sci-Fi
# 968	WEREWOLF LOLA	Action
# 969	WEST LION	Drama
# 970	WESTWARD SEABISCUIT	Classics
# 971	WHALE BIKINI	Foreign
# 972	WHISPERER GIANT	Sci-Fi
# 973	WIFE TURN	Documentary
# 974	WILD APOLLO	New
# 975	WILLOW TRACY	Family
# 976	WIND PHANTOM	Games
# 977	WINDOW SIDE	Travel
# 978	WISDOM WORKER	Comedy
# 979	WITCHES PANIC	Drama
# 980	WIZARD COLDBLOODED	Music
# 981	WOLVES DESIRE	Travel
# 982	WOMEN DORADO	Action
# 983	WON DARES	Music
# 984	WONDERFUL DROP	Foreign
# 985	WONDERLAND CHRISTMAS	Sci-Fi
# 986	WONKA SEA	Animation
# 987	WORDS HUNTER	Music
# 988	WORKER TARZAN	Travel
# 989	WORKING MICROCOSMOS	Travel
# 990	WORLD LEATHERNECKS	Horror
# 991	WORST BANGER	Action
# 992	WRATH MILE	Documentary
# 993	WRONG BEHAVIOR	Children
# 994	WYOMING STORM	New
# 995	YENTL IDAHO	Horror
# 996	YOUNG LANGUAGE	Documentary
# 997	YOUTH KICK	Music
# 998	ZHIVAGO CORE	Horror
# 999	ZOOLANDER FICTION	Children
# 1000	ZORRO ARK	Comedy
# cliente_id	cliente	total_alugueis
# 148	ELEANOR HUNT	46
# 526	KARL SEAL	45
# 144	CLARA SHAW	42
# 236	MARCIA DEAN	42
# 75	TAMMY SANDERS	41
# 197	SUE PETERS	40
# 469	WESLEY BULL	40
# 178	MARION SNYDER	39
# 137	RHONDA KENNEDY	39
# 468	TIM CARY	39
# 410	CURTIS IRBY	38
# 295	DAISY BATES	38
# 5	ELIZABETH BROWN	38
# 459	TOMMY COLLAZO	38
# 366	BRANDON HUEY	37
# 198	ELSIE KELLEY	37
# 176	JUNE CARROLL	37
# 257	MARSHA DOUGLAS	37
# 439	ALEXANDER FENNELL	36
# 29	ANGELA HERNANDEZ	36
# filme_id	titulo	duracao_do_filme	preco_da_locacao
# 141	CHICAGO NORTH	185	4.99
# 182	CONTROL ANTHEM	185	4.99
# 212	DARN FORRESTER	185	4.99
# 349	GANGS PRIDE	185	2.99
# 426	HOME PITY	185	4.99
# 609	MUSCLE BRIGHT	185	2.99
# 690	POND SEATTLE	185	2.99
# 817	SOLDIERS EVOLUTION	185	4.99
# 872	SWEET BROTHERHOOD	185	2.99
# 991	WORST BANGER	185	2.99
# 180	CONSPIRACY SPIRIT	184	2.99
# 198	CRYSTAL BREAKING	184	2.99
# 499	KING EVOLUTION	184	4.99
# 597	MOONWALKER FOOL	184	4.99
# 813	SMOOCHY CONTROL	184	0.99
# 820	SONS INTERVIEW	184	2.99
# 821	SORORITY QUEEN	184	0.99
# 886	THEORY MERMAID	184	0.99
# 128	CATCH AMISTAD	183	0.99
# 340	FRONTIER CABIN	183	4.99
# 767	SCALAWAG DUCK	183	4.99
# 973	WIFE TURN	183	4.99
# 996	YOUNG LANGUAGE	183	0.99
# 50	BAKED CLEOPATRA	182	2.99
# 591	MONSOON CAUSE	182	4.99
# 719	RECORDS ZORRO	182	4.99
# 721	REDS POCUS	182	4.99
# 765	SATURN NAME	182	4.99
# 774	SEARCHERS WAIT	182	2.99
# 24	ANALYZE HOOSIERS	181	2.99
# 406	HAUNTING PIANIST	181	0.99
# 435	HOTEL HAPPINESS	181	4.99
# 467	INTRIGUE WORST	181	0.99
# 473	JACKET FRISCO	181	2.99
# 510	LAWLESS VISION	181	4.99
# 535	LOVE SUICIDES	181	0.99
# 751	RUNAWAY TENENBAUMS	181	0.99
# 841	STAR OPERATION	181	2.99
# 974	WILD APOLLO	181	0.99
# 16	ALLEY EVOLUTION	180	2.99
# 174	CONFIDENTIAL INTERVIEW	180	4.99
# 454	IMPACT ALADDIN	180	0.99
# 584	MIXED DOORS	180	2.99
# 612	MUSSOLINI SPOILERS	180	2.99
# 615	NASH CHOCOLAT	180	2.99
# 818	SOMETHING DUCK	180	4.99
# 27	ANONYMOUS HUMAN	179	0.99
# 88	BORN SPINAL	179	4.99
# 126	CASUALTIES ENCINO	179	4.99
# 129	CAUSE DATE	179	2.99
# 323	FLIGHT LIES	179	4.99
# 496	KICK SAVANNAH	179	0.99
# 692	POTLUCK MIXED	179	2.99
# 720	REDEMPTION COMFORTS	179	2.99
# 803	SLACKER LIAISONS	179	4.99
# 885	TEXAS WATCH	179	0.99
# 897	TORQUE BOUND	179	4.99
# 944	VIRGIN DAISY	179	4.99
# 997	YOUTH KICK	179	0.99
# 256	DROP WATERFRONT	178	4.99
# 296	EXPRESS LONELY	178	2.99
# 344	FURY MURDER	178	0.99
# 453	IMAGE PRINCESS	178	2.99
# 460	INNOCENT USUAL	178	4.99
# 545	MADNESS ATTACKS	178	0.99
# 614	NAME DETECTIVE	178	4.99
# 738	ROCKETEER MOTHER	178	0.99
# 958	WARDROBE PHANTOM	178	2.99
# 993	WRONG BEHAVIOR	178	2.99
# 245	DOUBLE WRATH	177	0.99
# 248	DOZEN LION	177	4.99
# 280	EMPIRE MALKOVICH	177	0.99
# 557	MANCHURIAN CURTAIN	177	2.99
# 707	QUEST MUSSOLINI	177	2.99
# 729	RIDER CADDYSHACK	177	2.99
# 94	BRAVEHEART HUMAN	176	2.99
# 119	CAPER MOTIONS	176	0.99
# 201	CYCLONE FAMILY	176	2.99
# 249	DRACULA CRYSTAL	176	0.99
# 287	ENTRAPMENT SATISFACTION	176	0.99
# 352	GATHERING CALENDAR	176	0.99
# 380	GREEK EVERYONE	176	2.99
# 431	HOOSIERS BIRDCAGE	176	2.99
# 871	SWEDEN SHINING	176	4.99
# 992	WRATH MILE	176	0.99
# 61	BEAUTY GREASE	175	4.99
# 255	DRIVING POLISH	175	4.99
# 511	LAWRENCE LOVE	175	0.99
# 588	MODEL FISH	175	4.99
# 665	PATTON INTERVIEW	175	2.99
# 832	SPLASH GUMP	175	0.99
# 291	EVOLUTION ALTER	174	0.99
# 472	ITALIAN AFRICAN	174	4.99
# 474	JADE BUNCH	174	2.99
# 523	LIGHTS DEER	174	0.99
# 927	UPRISING UPTOWN	174	2.99
# 942	VIETNAM SMOOCHY	174	0.99
# 52	BALLROOM MOCKINGBIRD	173	0.99
# 179	CONQUERER NUTS	173	4.99
# 316	FIRE WOLVES	173	4.99
# 359	GLADIATOR WESTWARD	173	4.99
# 684	PIZZA JUMANJI	173	2.99
# 875	TALENTED HOMICIDE	173	0.99
# 938	VELVET TERMINATOR	173	4.99
# 177	CONNECTICUT TRAMP	172	4.99
# 190	CREEPERS KANE	172	4.99
# 298	EYES DRIVING	172	2.99
# 448	IDAHO LOVE	172	2.99
# 484	JERK PAYCHECK	172	2.99
# 628	NORTHWEST POLISH	172	2.99
# 890	TIGHTS DAWN	172	0.99
# 921	UNCUT SUICIDES	172	2.99
# 261	DUFFEL APOCALYPSE	171	0.99
# 483	JERICHO MULAN	171	2.99
# 503	KRAMER CHOCOLATE	171	2.99
# 549	MAGNOLIA FORRESTER	171	0.99
# 596	MOONSHINE CABIN	171	4.99
# 747	ROXANNE REBEL	171	0.99
# 906	TRAMP OTHERS	171	0.99
# 990	WORLD LEATHERNECKS	171	0.99
# 42	ARTIST COLDBLOODED	170	2.99
# 43	ATLANTIS CAUSE	170	2.99
# 250	DRAGON SQUAD	170	0.99
# 902	TRADING PINOCCHIO	170	4.99
# 6	AGENT TRUMAN	169	2.99
# 96	BREAKING HOME	169	2.99
# 413	HEDWIG ALTER	169	2.99
# 495	KENTUCKIAN GIANT	169	2.99
# 646	OUTBREAK DIVINE	169	0.99
# 822	SOUP WISDOM	169	0.99
# 29	ANTITRUST TOMATOES	168	2.99
# 265	DYING MAKER	168	4.99
# 401	HAROLD FRENCH	168	0.99
# 907	TRANSLATION SUMMER	168	0.99
# 115	CAMPUS REMEMBER	167	2.99
# 288	ESCAPE METROPOLIS	167	2.99
# 293	EXORCIST STING	167	2.99
# 456	INCH JET	167	4.99
# 517	LESSON CLEOPATRA	167	0.99
# 725	REQUIEM TYCOON	167	4.99
# 791	SHOW LORD	167	4.99
# 181	CONTACT ANONYMOUS	166	2.99
# 379	GREEDY ROOTS	166	0.99
# 580	MINE TITANS	166	4.99
# 600	MOTIONS DETAILS	166	0.99
# 608	MURDER ANTITRUST	166	2.99
# 153	CITIZEN SHREK	165	0.99
# 211	DARLING BREAKING	165	4.99
# 563	MASSACRE USUAL	165	4.99
# 819	SONG HEDWIG	165	0.99
# 825	SPEAKEASY DATE	165	2.99
# 156	CLERKS ANGELS	164	4.99
# 583	MISSION ZOOLANDER	164	4.99
# 925	UNITED PILOT	164	0.99
# 945	VIRGINIAN PLUTO	164	0.99
# 75	BIRD INDEPENDENCE	163	4.99
# 124	CASPER DRAGONFLY	163	4.99
# 290	EVERYONE CRAFT	163	0.99
# 358	GILMORE BOILED	163	0.99
# 500	KISS GLORY	163	4.99
# 706	QUEEN LUKE	163	4.99
# 850	STORY SIDE	163	0.99
# 49	BADMAN DAWN	162	2.99
# 74	BIRCH ANTITRUST	162	4.99
# 538	LOVERBOY ATTACKS	162	0.99
# 582	MIRACLE VIRTUAL	162	2.99
# 745	ROSES TREASURE	162	4.99
# 100	BROOKLYN DESERT	161	4.99
# 202	DADDY PITTSBURGH	161	4.99
# 345	GABLES METROPOLIS	161	0.99
# 498	KILLER INNOCENT	161	2.99
# 564	MASSAGE IMAGE	161	2.99
# 571	METAL ARMAGEDDON	161	2.99
# 619	NEIGHBORS CHARADE	161	0.99
# 636	OLEANDER CLUE	161	0.99
# 961	WASH HEAVENLY	161	4.99
# 59	BEAR GRACELAND	160	2.99
# 451	IGBY MAKER	160	4.99
# 604	MULAN MOON	160	0.99
# 606	MUMMY CREATURES	160	0.99
# 667	PEACH INNOCENT	160	2.99
# 847	STOCK GLASS	160	2.99
# 254	DRIVER ANNIE	159	2.99
# 332	FRANKENSTEIN STRANGER	159	0.99
# 554	MALKOVICH PET	159	2.99
# 622	NEWSIES STORY	159	0.99
# 691	POSEIDON FOREVER	159	4.99
# 969	WEST LION	159	4.99
# 286	ENOUGH RAGING	158	2.99
# 310	FEVER EMPIRE	158	4.99
# 327	FOOL MOCKINGBIRD	158	4.99
# 593	MONTEREY LABYRINTH	158	0.99
# 734	ROAD ROXANNE	158	4.99
# 777	SECRETARY ROUGE	158	4.99
# 418	HOBBIT ALIEN	157	0.99
# 457	INDEPENDENCE HOTEL	157	0.99
# 605	MULHOLLAND BEAST	157	2.99
# 661	PAST SUICIDES	157	4.99
# 896	TOOTSIE PILOT	157	0.99
# 949	VOLCANO TEXAS	157	0.99
# 315	FINDING ANACONDA	156	0.99
# 373	GRADUATE LORD	156	2.99
# 638	OPERATION OPERATION	156	2.99
# 809	SLIPPER FIDELITY	156	0.99
# 278	ELF MURDER	155	4.99
# 301	FAMILY SWEET	155	0.99
# 376	GRAPES FURY	155	0.99
# 528	LOLITA WORLD	155	2.99
# 701	PSYCHO SHRUNK	155	2.99
# 874	TADPOLE PARK	155	2.99
# 246	DOUBTFIRE LABYRINTH	154	4.99
# 263	DURHAM PANKY	154	4.99
# 365	GOLD RIVER	154	4.99
# 711	RAGING AIRPLANE	154	4.99
# 761	SANTA PARIS	154	2.99
# 762	SASSY PACKER	154	0.99
# 792	SHREK LICENSE	154	2.99
# 33	APOLLO TEEN	153	2.99
# 47	BABY HALL	153	4.99
# 193	CROSSROADS CASUALTIES	153	2.99
# 272	EDGE KISSING	153	4.99
# 367	GOLDMINE TYCOON	153	0.99
# 513	LEATHERNECKS DWARFS	153	2.99
# 731	RIGHT CRANES	153	4.99
# 740	ROLLERCOASTER BRINGING	153	2.99
# 749	RULES HUMAN	153	4.99
# 131	CENTER DINOSAUR	152	4.99
# 279	ELIZABETH SHANE	152	4.99
# 539	LUCK OPUS	152	2.99
# 801	SISTER FREDDY	152	4.99
# 880	TELEMARK HEARTBREAKERS	152	2.99
# 898	TOURIST PELICAN	152	4.99
# 917	TUXEDO MILE	152	2.99
# 918	TWISTED PIRATES	152	4.99
# 952	WAGON JAWS	152	2.99
# 64	BEETHOVEN EXORCIST	151	0.99
# 121	CAROL TEXAS	151	2.99
# 439	HUNCHBACK IMPOSSIBLE	151	4.99
# 562	MASKED BUBBLE	151	0.99
# 769	SCHOOL JACKET	151	4.99
# 834	SPOILERS HELLFIGHTERS	151	0.99
# 851	STRAIGHT HOURS	151	0.99
# 13	ALI FOREVER	150	4.99
# 73	BINGO TALENTED	150	2.99
# 149	CHRISTMAS MOONSHINE	150	0.99
# 155	CLEOPATRA DEVIL	150	0.99
# 381	GRINCH MASSAGE	150	4.99
# 446	HYSTERICAL GRAIL	150	4.99
# 754	RUSHMORE MERMAID	150	2.99
# 764	SATURDAY LAMBS	150	4.99
# 166	COLOR PHILADELPHIA	149	2.99
# 424	HOLOCAUST HIGHBALL	149	0.99
# 579	MINDS TRUMAN	149	4.99
# 624	NIGHTMARE CHILL	149	4.99
# 733	RIVER OUTLAW	149	0.99
# 830	SPIRIT FLINTSTONES	149	0.99
# 40	ARMY FLINTSTONES	148	0.99
# 80	BLANKET BEVERLY	148	2.99
# 271	EASY GLADIATOR	148	4.99
# 317	FIREBALL PHILADELPHIA	148	0.99
# 324	FLINTSTONES HAPPINESS	148	4.99
# 648	OUTLAW HANKY	148	4.99
# 879	TELEGRAPH VOYAGE	148	4.99
# 35	ARACHNOPHOBIA ROLLERCOASTER	147	2.99
# 232	DIRTY ACE	147	2.99
# 521	LIES TREATMENT	147	4.99
# 544	MADISON TRAP	147	2.99
# 569	MENAGERIE RUSHMORE	147	2.99
# 709	RACER EGG	147	2.99
# 715	RANGE MOONWALKER	147	4.99
# 770	SCISSORHANDS SLUMS	147	2.99
# 810	SLUMS DUCK	147	0.99
# 136	CHAPLIN LICENSE	146	2.99
# 185	COWBOY DOOM	146	2.99
# 391	HALF OUTFIELD	146	2.99
# 394	HAMLET WISDOM	146	2.99
# 602	MOURNING PURPLE	146	0.99
# 325	FLOATS GARDEN	145	2.99
# 632	NUTS TIES	145	4.99
# 666	PAYCHECK WAIT	145	4.99
# 739	ROCKY WAR	145	4.99
# 750	RUN PACIFIC	145	0.99
# 930	VACATION BOONDOCK	145	2.99
# 941	VIDEOTAPE ARSENIC	145	4.99
# 206	DANCING FEVER	144	0.99
# 299	FACTORY DRAGON	144	0.99
# 508	LAMBS CINCINATTI	144	4.99
# 650	PACIFIC AMISTAD	144	0.99
# 695	PRESIDENT BANG	144	4.99
# 857	STRICTLY SCARFACE	144	2.99
# 899	TOWERS HURRICANE	144	0.99
# 946	VIRTUAL SPOILERS	144	4.99
# 151	CINCINATTI WHISPERER	143	4.99
# 157	CLOCKWORK PARADISE	143	0.99
# 191	CROOKED FROGMEN	143	0.99
# 228	DETECTIVE VISION	143	0.99
# 281	ENCINO ELF	143	0.99
# 823	SOUTH WAIT	143	2.99
# 843	STEEL SANTA	143	4.99
# 70	BIKINI BORROWERS	142	4.99
# 143	CHILL LUCK	142	0.99
# 308	FERRIS MOTHER	142	2.99
# 578	MILLION ACE	142	4.99
# 895	TOMORROW HUSTLER	142	2.99
# 901	TRACY CIDER	142	0.99
# 935	VANISHED GARDEN	142	0.99
# 233	DISCIPLE MOTHER	141	0.99
# 266	DYNAMITE TARZAN	141	0.99
# 419	HOCUS FRIDA	141	2.99
# 428	HOMICIDE PEACH	141	2.99
# 501	KISSING DOLLS	141	4.99
# 827	SPICE SORORITY	141	4.99
# 863	SUN CONFESSIONS	141	0.99
# 267	EAGLES PANKY	140	4.99
# 372	GRACELAND DYNAMITE	140	4.99
# 518	LIAISONS SWEET	140	4.99
# 525	LOATHING LEGALLY	140	0.99
# 844	STEERS ARMAGEDDON	140	4.99
# 163	CLYDE THEORY	139	0.99
# 189	CREATURES SHAKESPEARE	139	0.99
# 244	DORADO NOTTING	139	4.99
# 385	GROUNDHOG UNCUT	139	4.99
# 432	HOPE TOOTSIE	139	2.99
# 434	HORROR REIGN	139	0.99
# 793	SHRUNK DIVINE	139	2.99
# 853	STRANGER STRANGERS	139	4.99
# 903	TRAFFIC HOBBIT	139	4.99
# 948	VOICE PEACH	139	0.99
# 988	WORKER TARZAN	139	2.99
# 294	EXPECATIONS NATURAL	138	4.99
# 519	LIBERTY MAGNIFICENT	138	2.99
# 551	MAIDEN HOME	138	4.99
# 687	POCUS PULP	138	0.99
# 829	SPINAL ROCKY	138	2.99
# 831	SPIRITED CASUALTIES	138	0.99
# 41	ARSENIC INDEPENDENCE	137	0.99
# 382	GRIT CLOCKWORK	137	0.99
# 522	LIFE TWISTED	137	2.99
# 531	LOSE INCH	137	0.99
# 676	PHILADELPHIA WIFE	137	4.99
# 689	POLLOCK DELIVERANCE	137	2.99
# 771	SCORPION APOLLO	137	4.99
# 806	SLEEPY JAPANESE	137	2.99
# 975	WILLOW TRACY	137	2.99
# 12	ALASKA PHANTOM	136	0.99
# 99	BRINGING HYSTERICAL	136	2.99
# 188	CRAZY HOME	136	2.99
# 422	HOLLOW JEOPARDY	136	4.99
# 553	MAKER GABLES	136	0.99
# 677	PIANIST OUTFIELD	136	0.99
# 716	REAP UNFAITHFUL	136	2.99
# 836	SQUAD FISH	136	2.99
# 900	TOWN ARK	136	2.99
# 117	CANDLES GRAPES	135	4.99
# 252	DREAM PICKUP	135	2.99
# 377	GREASE YOUTH	135	0.99
# 458	INDIAN LOVE	135	0.99
# 475	JAPANESE RUN	135	0.99
# 590	MONEY HAROLD	135	2.99
# 796	SIERRA DIVIDE	135	0.99
# 865	SUNRISE LEAGUE	135	4.99
# 887	THIEF PELICAN	135	4.99
# 955	WALLS ARTIST	135	4.99
# 492	JUNGLE CLOSER	134	0.99
# 682	PITTSBURGH HUNCHBACK	134	4.99
# 736	ROBBERY BRIGHT	134	0.99
# 833	SPLENDOR PATTON	134	0.99
# 967	WEEKEND PERSONAL	134	2.99
# 103	BUCKET BROTHERHOOD	133	4.99
# 200	CURTAIN VIDEOTAPE	133	0.99
# 251	DRAGONFLY STRANGERS	133	4.99
# 335	FREEDOM CLEOPATRA	133	0.99
# 555	MALLRATS UNITED	133	0.99
# 148	CHOCOLATE DUCK	132	2.99
# 260	DUDE BLINDNESS	132	4.99
# 618	NECKLACE OUTBREAK	132	0.99
# 685	PLATOON INSTINCT	132	4.99
# 802	SKY MIRACLE	132	2.99
# 855	STREAK RIDGEMONT	132	0.99
# 905	TRAINSPOTTING STRANGERS	132	4.99
# 950	VOLUME HOUSE	132	4.99
# 302	FANTASIA PARK	131	2.99
# 328	FOREVER CANDIDATE	131	2.99
# 447	ICE CROSSING	131	2.99
# 620	NEMO CAMPUS	131	2.99
# 637	OPEN AFRICAN	131	4.99
# 5	AFRICAN EGG	130	2.99
# 210	DARKO DORADO	130	4.99
# 304	FARGO GANDHI	130	2.99
# 476	JASON TRAP	130	2.99
# 552	MAJESTIC FLOATS	130	0.99
# 839	STALLION SUNDANCE	130	0.99
# 21	AMERICAN CIRCUS	129	4.99
# 56	BAREFOOT MANCHURIAN	129	2.99
# 371	GOSFORD DONNIE	129	4.99
# 610	MUSIC BOONDOCK	129	0.99
# 647	OUTFIELD MASSACRE	129	0.99
# 804	SLEEPING SUSPECTS	129	4.99
# 924	UNFORGIVEN ZOOLANDER	129	0.99
# 346	GALAXY SWEETHEARTS	128	4.99
# 420	HOLES BRANNIGAN	128	4.99
# 479	JEDI BENEATH	128	0.99
# 629	NOTORIOUS REUNION	128	0.99
# 656	PAPI NECKLACE	128	0.99
# 929	USUAL UNTOUCHABLES	128	4.99
# 960	WARS PLUTO	128	2.99
# 36	ARGONAUTS TOWN	127	0.99
# 389	GUNFIGHTER MUSSOLINI	127	2.99
# 556	MALTESE HOPE	127	4.99
# 781	SEVEN SWARM	127	4.99
# 858	SUBMARINE BED	127	4.99
# 11	ALAMO VIDEOTAPE	126	0.99
# 277	ELEPHANT TROJAN	126	4.99
# 333	FREAKY POCUS	126	2.99
# 594	MONTEZUMA COMMAND	126	0.99
# 652	PAJAMA JAWBREAKER	126	0.99
# 800	SINNERS ATLANTIS	126	2.99
# 933	VAMPIRE WHALE	126	4.99
# 982	WOMEN DORADO	126	0.99
# 984	WONDERFUL DROP	126	2.99
# 105	BULL SHAWSHANK	125	0.99
# 241	DONNIE ALLEY	125	0.99
# 319	FISH OPUS	125	2.99
# 353	GENTLEMEN STAGE	125	2.99
# 441	HUNTER ALTER	125	2.99
# 758	SAINTS BRIDE	125	2.99
# 787	SHINING ROSES	125	0.99
# 145	CHISUM BEHAVIOR	124	4.99
# 158	CLONES PINOCCHIO	124	2.99
# 487	JINGLE SAGEBRUSH	124	4.99
# 826	SPEED SUIT	124	4.99
# 95	BREAKFAST GOLDFINGER	123	4.99
# 321	FLASH WARS	123	4.99
# 461	INSECTS STONE	123	0.99
# 561	MASK PEACH	123	2.99
# 722	REEF SALUTE	123	0.99
# 870	SWARM GOLD	123	0.99
# 936	VANISHING ROCKY	123	2.99
# 58	BEACH HEARTBREAKERS	122	2.99
# 68	BETRAYED REAR	122	4.99
# 142	CHICKEN HELLFIGHTERS	122	0.99
# 175	CONFUSED CANDLES	122	2.99
# 218	DECEIVER BETRAYED	122	0.99
# 239	DOGMA FAMILY	122	4.99
# 297	EXTRAORDINARY CONQUERER	122	2.99
# 436	HOURS RAGE	122	0.99
# 452	ILLUSION AMELIE	122	0.99
# 576	MIGHTY LUCK	122	2.99
# 934	VANILLA DAY	122	4.99
# 37	ARIZONA BANG	121	2.99
# 86	BOOGIE AMELIE	121	4.99
# 93	BRANNIGAN SUNRISE	121	4.99
# 207	DANGEROUS UPTOWN	121	4.99
# 403	HARRY IDAHO	121	4.99
# 490	JUMANJI BLADE	121	2.99
# 658	PARIS WEEKEND	121	2.99
# 704	PURE RUNNER	121	2.99
# categoria_id	categoria	quantidade_filmes
# 15	Sports	74
# 9	Foreign	73
# 8	Family	69
# 6	Documentary	68
# 2	Animation	66
# 1	Action	64
# 13	New	63
# 7	Drama	62
# 10	Games	61
# 14	Sci-Fi	61
# 3	Children	60
# 5	Comedy	58
# 4	Classics	57
# 16	Travel	57
# 11	Horror	56
# 12	Music	51
# ator_id	ator	quantidade_filmes
# 107	GINA DEGENERES	42
# 102	WALTER TORN	41
# 198	MARY KEITEL	40
# 181	MATTHEW CARREY	39
# 23	SANDRA KILMER	37
# 81	SCARLETT DAMON	36
# 144	ANGELA WITHERSPOON	35
# 106	GROUCHO DUNST	35
# 60	HENRY BERRY	35
# 13	UMA WOOD	35
# 37	VAL BOLGER	35
# 158	VIVIEN BASINGER	35
# 65	ANGELA HUDSON	34
# 150	JAYNE NOLTE	34
# 92	KIRSTEN AKROYD	34
# 105	SIDNEY CROWE	34
# 108	WARREN NOLTE	34
# 146	ALBERT JOHANSSON	33
# 83	BEN WILLIS	33
# 111	CAMERON ZELLWEGER	33
# 139	EWAN GOODING	33
# 27	JULIA MCQUEEN	33
# 94	KENNETH TORN	33
# 127	KEVIN GARLAND	33
# 197	REESE WEST	33
# 187	RENEE BALL	33
# 117	RENEE TRACY	33
# 26	RIP CRAWFORD	33
# 90	SEAN GUINESS	33
# 101	SUSAN DAVIS	33
# 58	CHRISTIAN AKROYD	32
# 136	ED MANSFIELD	32
# 157	GRETA MALDEN	32
# 161	HARVEY HOPE	32
# 17	HELEN VOIGHT	32
# 123	JULIANNE DENCH	32
# 50	NATALIE HOPKINS	32
# 45	REESE KILMER	32
# 119	WARREN JACKMAN	32
# 140	WHOOPI HURT	32
# 125	ALBERT NOLTE	31
# 76	ANGELINA ASTAIRE	31
# 95	DARYL WAHLBERG	31
# 147	FAY WINSLET	31
# 155	IAN TANDY	31
# 142	JADA RYDER	31
# 84	JAMES PITT	31
# 12	KARL BERRY	31
# 66	MARY TANDY	31
# 85	MINNIE ZELLWEGER	31
# 104	PENELOPE CRONYN	31
# 143	RIVER DEAN	31
# 149	RUSSELL TEMPLE	31
# 168	WILL WILSON	31
# 28	WOODY HOFFMAN	31
# 82	WOODY JOLIE	31
# 196	BELA WALKEN	30
# 128	CATE MCQUEEN	30
# 129	DARYL CRAWFORD	30
# 7	GRACE MOSTEL	30
# 191	GREGORY GOODING	30
# 57	JUDE CRUISE	30
# 20	LUCILLE TRACY	30
# 103	MATTHEW LEIGH	30
# 53	MENA TEMPLE	30
# 185	MICHAEL BOLGER	30
# 44	NICK STALLONE	30
# 64	RAY JOHANSSON	30
# 133	RICHARD PENN	30
# 68	RIP WINSLET	30
# 188	ROCK DUKAKIS	30
# 14	VIVIEN BERGEN	30
# 29	ALEC WAYNE	29
# 36	BURT DUKAKIS	29
# 179	ED GUINESS	29
# 184	HUMPHREY GARLAND	29
# 62	JAYNE NEESON	29
# 41	JODIE DEGENERES	29
# 192	JOHN SUVARI	29
# 40	JOHNNY CAGE	29
# 5	JOHNNY LOLLOBRIGIDA	29
# 176	JON CHASE	29
# 169	KENNETH HOFFMAN	29
# 141	CATE HARRIS	28
# 15	CUBA OLIVIER	28
# 56	DAN HARRIS	28
# 39	GOLDIE BRODY	28
# 115	HARRISON BALE	28
# 145	KIM ALLEN	28
# 79	MAE HOFFMAN	28
# 154	MERYL GIBSON	28
# 74	MILLA KEITEL	28
# 171	OLYMPIA PFEIFFER	28
# 80	RALPH CRUZ	28
# 173	ALAN DREYFUSS	27
# 49	ANNE CRONYN	27
# 190	AUDREY BAILEY	27
# 98	CHRIS BRIDGES	27
# 59	DUSTIN TAUTOU	27
# 16	FRED COSTNER	27
# 177	GENE MCKELLEN	27
# 86	GREG CHAPLIN	27
# 130	GRETA KEITEL	27
# 195	JAYNE SILVERSTONE	27
# 21	KIRSTEN PALTROW	27
# 97	MEG HAWKE	27
# 113	MORGAN HOPKINS	27
# 137	MORGAN WILLIAMS	27
# 120	PENELOPE MONROE	27
# 42	TOM MIRANDA	27
# 175	WILLIAM HACKMAN	27
# 165	AL GARLAND	26
# 52	CARMEN HUNT	26
# 22	ELVIS MARX	26
# 48	FRANCES DAY-LEWIS	26
# 73	GARY PENN	26
# 151	GEOFFREY HESTON	26
# 78	GROUCHO SINATRA	26
# 164	HUMPHREY WILLIS	26
# 99	JIM MOSTEL	26
# 43	KIRK JOVOVICH	26
# 159	LAURA BRODY	26
# 167	LAURENCE BULLOCK	26
# 124	SCARLETT BENING	26
# 72	SEAN WILLIAMS	26
# cliente_id	cliente	gasto_total
# 526	KARL SEAL	221.55
# 148	ELEANOR HUNT	216.54
# 144	CLARA SHAW	195.58
# 178	MARION SNYDER	194.61
# 137	RHONDA KENNEDY	194.61
# 459	TOMMY COLLAZO	186.62
# 469	WESLEY BULL	177.60
# 468	TIM CARY	175.61
# 236	MARCIA DEAN	175.58
# 181	ANA BRADLEY	174.66
# 176	JUNE CARROLL	173.63
# 50	DIANE COLLINS	169.65
# 259	LENA JENSEN	168.68
# 522	ARNOLD HAVENS	167.67
# 410	CURTIS IRBY	167.62
# 403	MIKE WAY	166.65
# 295	DAISY BATES	162.62
# 209	TONYA CHAPMAN	161.68
# 373	LOUIS LEONE	161.65
# 470	GORDON ALLARD	160.68
# 187	BRITTANY RILEY	159.72
# 550	GUY BROWNLEE	159.68
# 462	WARREN SHERROD	159.67
# 267	MARGIE WADE	159.64
# 293	MAE FLETCHER	158.69
# 372	STEVE MACKENZIE	158.66
# 368	HARRY ARCE	157.65
# 273	PRISCILLA LOWE	157.65
# 346	ARTHUR SIMPKINS	155.68
# 21	MICHELLE CLARK	155.65
# 75	TAMMY SANDERS	155.59
# 197	SUE PETERS	154.60
# 119	SHERRY MARSHALL	153.66
# 532	NEIL RENNER	152.68
# 390	SHAWN HEATON	152.67
# 26	JESSICA HALL	152.66
# 506	LESLIE SEWARD	152.65
# 274	NAOMI JENNINGS	152.65
# 366	BRANDON HUEY	152.63
# 454	ALEX GRESHAM	151.67
# 7	MARIA MILLER	151.67
# 211	STACEY MONTGOMERY	151.66
# 196	ALMA AUSTIN	151.65
# 439	ALEXANDER FENNELL	151.64
# 257	MARSHA DOUGLAS	151.63
# 360	RALPH MADRIGAL	150.66
# filme_id	titulo	receita_total	total_alugueis
# 879	TELEGRAPH VOYAGE	231.73	27
# 973	WIFE TURN	223.69	31
# 1000	ZORRO ARK	214.69	31
# 369	GOODFELLAS SALUTE	209.69	31
# 764	SATURDAY LAMBS	204.72	28
# cliente_id	cliente	email	cidade	pais
# 398	ANTONIO MEEK	ANTONIO.MEEK@sakilacustomer.org	Bagé	Brazil
# 130	CHARLOTTE HUNTER	CHARLOTTE.HUNTER@sakilacustomer.org	Águas Lindas de Goiás	Brazil
# 551	CLAYTON BARBEE	CLAYTON.BARBEE@sakilacustomer.org	Alvorada	Brazil
# 544	CODY NOLEN	CODY.NOLEN@sakilacustomer.org	São Bernardo do Campo	Brazil
# 310	DANIEL CABRAL	DANIEL.CABRAL@sakilacustomer.org	Ibirité	Brazil
# 39	DEBRA NELSON	DEBRA.NELSON@sakilacustomer.org	Vila Velha	Brazil
# 74	DENISE KELLY	DENISE.KELLY@sakilacustomer.org	Rio Claro	Brazil
# 126	ELLEN SIMPSON	ELLEN.SIMPSON@sakilacustomer.org	Poá	Brazil
# 47	FRANCES PARKER	FRANCES.PARKER@sakilacustomer.org	Juazeiro do Norte	Brazil
# 443	FRANCISCO SKIDMORE	FRANCISCO.SKIDMORE@sakilacustomer.org	São Leopoldo	Brazil
# 314	GEORGE LINTON	GEORGE.LINTON@sakilacustomer.org	Sorocaba	Brazil
# 342	HAROLD MARTINO	HAROLD.MARTINO@sakilacustomer.org	Boa Vista	Brazil
# 183	IDA ANDREWS	IDA.ANDREWS@sakilacustomer.org	Luziânia	Brazil
# 77	JANE BENNETT	JANE.BENNETT@sakilacustomer.org	Araçatuba	Brazil
# 374	JEREMY HURTADO	JEREMY.HURTADO@sakilacustomer.org	Vitória de Santo Antão	Brazil
# 427	JESUS MCCARTNEY	JESUS.MCCARTNEY@sakilacustomer.org	Guarujá	Brazil
# 307	JOSEPH JOY	JOSEPH.JOY@sakilacustomer.org	Angra dos Reis	Brazil
# 354	JUSTIN NGO	JUSTIN.NGO@sakilacustomer.org	Santo André	Brazil
# 591	KENT ARSENAULT	KENT.ARSENAULT@sakilacustomer.org	Juiz de Fora	Brazil
# 246	MARIAN MENDOZA	MARIAN.MENDOZA@sakilacustomer.org	Maringá	Brazil
# 178	MARION SNYDER	MARION.SNYDER@sakilacustomer.org	Santa Bárbara d´Oeste	Brazil
# 254	MAXINE SILVA	MAXINE.SILVA@sakilacustomer.org	Poços de Caldas	Brazil
# 216	NATALIE MEYER	NATALIE.MEYER@sakilacustomer.org	Aparecida de Goiânia	Brazil
# 362	NICHOLAS BARFIELD	NICHOLAS.BARFIELD@sakilacustomer.org	Belém	Brazil
# 229	TAMARA NGUYEN	TAMARA.NGUYEN@sakilacustomer.org	Anápolis	Brazil
# 206	TERRI VASQUEZ	TERRI.VASQUEZ@sakilacustomer.org	Blumenau	Brazil
# 325	TIMOTHY BUNN	TIMOTHY.BUNN@sakilacustomer.org	Brasília	Brazil
# 92	TINA SIMMONS	TINA.SIMMONS@sakilacustomer.org	Goiânia	Brazil
# cliente_id	cliente	total_alugueis
# 15	HELEN HARRIS	32
# auditoria_id	filme_id	titulo_anterior	titulo_novo	preco_anterior	preco_novo	data_alteracao	tipo_operacao	usuario_banco
# 1	1	ACADEMY DINOSAUR	ACADEMY DINOSAUR	0.99	1.09	2026-06-30 16:31:01	UPDATE	root@localhost
# cliente_id	cliente	total_gasto	quantidade_pagamentos	atualizado_em
# 526	KARL SEAL	221.55	45	2026-06-30 16:31:01
# 148	ELEANOR HUNT	216.54	46	2026-06-30 16:31:01
# 144	CLARA SHAW	195.58	42	2026-06-30 16:31:01
# 178	MARION SNYDER	194.61	39	2026-06-30 16:31:01
# 137	RHONDA KENNEDY	194.61	39	2026-06-30 16:31:01
# 459	TOMMY COLLAZO	186.62	38	2026-06-30 16:31:01
# 469	WESLEY BULL	177.60	40	2026-06-30 16:31:01
# 468	TIM CARY	175.61	39	2026-06-30 16:31:01
# 236	MARCIA DEAN	175.58	42	2026-06-30 16:31:01
# 181	ANA BRADLEY	174.66	34	2026-06-30 16:31:01
# 176	JUNE CARROLL	173.63	37	2026-06-30 16:31:01
# 50	DIANE COLLINS	169.65	35	2026-06-30 16:31:01
# 259	LENA JENSEN	168.68	32	2026-06-30 16:31:01
# 522	ARNOLD HAVENS	167.67	33	2026-06-30 16:31:01
# 410	CURTIS IRBY	167.62	38	2026-06-30 16:31:01
# 403	MIKE WAY	166.65	35	2026-06-30 16:31:01
# 295	DAISY BATES	162.62	38	2026-06-30 16:31:01
# 209	TONYA CHAPMAN	161.68	32	2026-06-30 16:31:01
# 373	LOUIS LEONE	161.65	35	2026-06-30 16:31:01
# 470	GORDON ALLARD	160.68	32	2026-06-30 16:31:01
# 187	BRITTANY RILEY	159.72	28	2026-06-30 16:31:01
# 550	GUY BROWNLEE	159.68	32	2026-06-30 16:31:01
# 462	WARREN SHERROD	159.67	33	2026-06-30 16:31:01
# 267	MARGIE WADE	159.64	36	2026-06-30 16:31:01
# 293	MAE FLETCHER	158.69	31	2026-06-30 16:31:01
# 372	STEVE MACKENZIE	158.66	34	2026-06-30 16:31:01
# 368	HARRY ARCE	157.65	35	2026-06-30 16:31:01
# 273	PRISCILLA LOWE	157.65	35	2026-06-30 16:31:01
# 346	ARTHUR SIMPKINS	155.68	32	2026-06-30 16:31:01
# 21	MICHELLE CLARK	155.65	35	2026-06-30 16:31:01
# 75	TAMMY SANDERS	155.59	41	2026-06-30 16:31:01
# 197	SUE PETERS	154.60	40	2026-06-30 16:31:01
# 119	SHERRY MARSHALL	153.66	34	2026-06-30 16:31:01
# 532	NEIL RENNER	152.68	32	2026-06-30 16:31:01
# 390	SHAWN HEATON	152.67	33	2026-06-30 16:31:01
# 26	JESSICA HALL	152.66	34	2026-06-30 16:31:01
# 506	LESLIE SEWARD	152.65	35	2026-06-30 16:31:01
# 274	NAOMI JENNINGS	152.65	35	2026-06-30 16:31:01
# 366	BRANDON HUEY	152.63	37	2026-06-30 16:31:01
# 454	ALEX GRESHAM	151.67	33	2026-06-30 16:31:01
# 7	MARIA MILLER	151.67	33	2026-06-30 16:31:01
# 211	STACEY MONTGOMERY	151.66	34	2026-06-30 16:31:01
# 196	ALMA AUSTIN	151.65	35	2026-06-30 16:31:01
# 439	ALEXANDER FENNELL	151.64	36	2026-06-30 16:31:01
# 257	MARSHA DOUGLAS	151.63	37	2026-06-30 16:31:01
# 360	RALPH MADRIGAL	150.66	34	2026-06-30 16:31:01
# Db	Name	Type	Definer	Modified	Created	Security_type	Comment	character_set_client	collation_connection	Database Collation
# locadora	atualizar_resumo_gasto_clientes	PROCEDURE	root@localhost	2026-06-30 16:31:01	2026-06-30 16:31:01	DEFINER		utf8mb4	utf8mb4_general_ci	utf8mb4_unicode_ci
# locadora	clientes_por_pais	PROCEDURE	root@localhost	2026-06-30 16:31:01	2026-06-30 16:31:01	DEFINER		utf8mb4	utf8mb4_general_ci	utf8mb4_unicode_ci
# locadora	total_alugueis_cliente	PROCEDURE	root@localhost	2026-06-30 16:31:01	2026-06-30 16:31:01	DEFINER		utf8mb4	utf8mb4_general_ci	utf8mb4_unicode_ci
# Trigger	Event	Table	Statement	Timing	Created	sql_mode	Definer	character_set_client	collation_connection	Database Collation
# trg_validar_preco_filme_insert	INSERT	filme	BEGIN\n    IF NEW.preco_da_locacao IS NULL\n       OR NEW.preco_da_locacao < 1.00 THEN\n\n        SIGNAL SQLSTATE '45000'\n        SET MESSAGE_TEXT =\n            'Preço de locação inválido. O valor mínimo permitido é R$ 1,00.';\n    END IF;\nEND	BEFORE	2026-06-30 16:31:01.42	STRICT_TRANS_TABLES,ERROR_FOR_DIVISION_BY_ZERO,NO_AUTO_CREATE_USER,NO_ENGINE_SUBSTITUTION	root@localhost	utf8mb4	utf8mb4_general_ci	utf8mb4_unicode_ci
# trg_auditoria_filme_update	UPDATE	filme	BEGIN\n    INSERT INTO auditoria_filme (\n        filme_id,\n        titulo_anterior,\n        titulo_novo,\n        preco_anterior,\n        preco_novo,\n        data_alteracao,\n        tipo_operacao,\n        usuario_banco\n    ) VALUES (\n        OLD.filme_id,\n        OLD.titulo,\n        NEW.titulo,\n        OLD.preco_da_locacao,\n        NEW.preco_da_locacao,\n        CURRENT_TIMESTAMP,\n        'UPDATE',\n        CURRENT_USER()\n    );\nEND	AFTER	2026-06-30 16:31:01.41	STRICT_TRANS_TABLES,ERROR_FOR_DIVISION_BY_ZERO,NO_AUTO_CREATE_USER,NO_ENGINE_SUBSTITUTION	root@localhost	utf8mb4	utf8mb4_general_ci	utf8mb4_unicode_ci
# trg_atualizar_resumo_gasto_pagamento	INSERT	pagamento	BEGIN\n    INSERT INTO resumo_gasto_cliente (\n        cliente_id,\n        total_gasto,\n        quantidade_pagamentos,\n        atualizado_em\n    ) VALUES (\n        NEW.cliente_id,\n        NEW.valor,\n        1,\n        CURRENT_TIMESTAMP\n    )\n    ON DUPLICATE KEY UPDATE\n        total_gasto =\n            total_gasto + NEW.valor,\n        quantidade_pagamentos =\n            quantidade_pagamentos + 1,\n        atualizado_em =\n            CURRENT_TIMESTAMP;\nEND	AFTER	2026-06-30 16:31:01.45	STRICT_TRANS_TABLES,ERROR_FOR_DIVISION_BY_ZERO,NO_AUTO_CREATE_USER,NO_ENGINE_SUBSTITUTION	root@localhost	utf8mb4	utf8mb4_general_ci	utf8mb4_unicode_ci
#
# Consultas, procedures e triggers executadas com sucesso.
# Arquivo SQL criado em: /content/NomeSobrenome_Sakila_SQL.sql

# %%
import subprocess

consultas_verificacao = "\nUSE locadora;\n\nSELECT\n    'CONTAGEM DAS TABELAS PRINCIPAIS' AS etapa;\n\nSELECT 'Filmes' AS tabela, COUNT(*) AS total FROM filme\nUNION ALL\nSELECT 'Clientes', COUNT(*) FROM cliente\nUNION ALL\nSELECT 'Aluguéis', COUNT(*) FROM aluguel\nUNION ALL\nSELECT 'Pagamentos', COUNT(*) FROM pagamento\nUNION ALL\nSELECT 'Atores', COUNT(*) FROM ator\nUNION ALL\nSELECT 'Categorias', COUNT(*) FROM categoria;\n\nSELECT\n    'TOP 5 FILMES MAIS LUCRATIVOS' AS etapa;\n\nSELECT\n    f.titulo,\n    ROUND(SUM(p.valor), 2) AS receita_total,\n    COUNT(DISTINCT a.aluguel_id) AS total_alugueis\nFROM pagamento AS p\nINNER JOIN aluguel AS a\n    ON a.aluguel_id = p.aluguel_id\nINNER JOIN inventario AS i\n    ON i.inventario_id = a.inventario_id\nINNER JOIN filme AS f\n    ON f.filme_id = i.filme_id\nGROUP BY\n    f.filme_id,\n    f.titulo\nORDER BY\n    receita_total DESC,\n    f.titulo\nLIMIT 5;\n\nSELECT\n    'PROCEDURES CRIADAS' AS etapa;\n\nSHOW PROCEDURE STATUS\nWHERE Db = 'locadora';\n\nSELECT\n    'TRIGGERS CRIADAS' AS etapa;\n\nSHOW TRIGGERS\nFROM locadora;\n"

resultado = subprocess.run(
    [
        "mariadb",
        "-u",
        "root",
        "--table",
        "--default-character-set=utf8mb4",
        "-e",
        consultas_verificacao
    ],
    text=True,
    capture_output=True
)

print(resultado.stdout)

if resultado.returncode != 0:
    print(resultado.stderr)
    raise RuntimeError(
        "Erro durante a verificação final."
    )

print("Atividade concluída.")
# Out:
# +---------------------------------+
# | etapa                           |
# +---------------------------------+
# | CONTAGEM DAS TABELAS PRINCIPAIS |
# +---------------------------------+
# +------------+-------+
# | tabela     | total |
# +------------+-------+
# | Filmes     |  1000 |
# | Clientes   |   599 |
# | Aluguéis   | 16044 |
# | Pagamentos | 16044 |
# | Atores     |   200 |
# | Categorias |    16 |
# +------------+-------+
# +------------------------------+
# | etapa                        |
# +------------------------------+
# | TOP 5 FILMES MAIS LUCRATIVOS |
# +------------------------------+
# +-------------------+---------------+----------------+
# | titulo            | receita_total | total_alugueis |
# +-------------------+---------------+----------------+
# | TELEGRAPH VOYAGE  |        231.73 |             27 |
# | WIFE TURN         |        223.69 |             31 |
# | ZORRO ARK         |        214.69 |             31 |
# | GOODFELLAS SALUTE |        209.69 |             31 |
# | SATURDAY LAMBS    |        204.72 |             28 |
# +-------------------+---------------+----------------+
# +--------------------+
# | etapa              |
# +--------------------+
# | PROCEDURES CRIADAS |
# +--------------------+
# +----------+---------------------------------+-----------+----------------+---------------------+---------------------+---------------+---------+----------------------+----------------------+--------------------+
# | Db       | Name                            | Type      | Definer        | Modified            | Created             | Security_type | Comment | character_set_client | collation_connection | Database Collation |
# +----------+---------------------------------+-----------+----------------+---------------------+---------------------+---------------+---------+----------------------+----------------------+--------------------+
# | locadora | atualizar_resumo_gasto_clientes | PROCEDURE | root@localhost | 2026-06-30 16:31:01 | 2026-06-30 16:31:01 | DEFINER       |         | utf8mb4              | utf8mb4_general_ci   | utf8mb4_unicode_ci |
# | locadora | clientes_por_pais               | PROCEDURE | root@localhost | 2026-06-30 16:31:01 | 2026-06-30 16:31:01 | DEFINER       |         | utf8mb4              | utf8mb4_general_ci   | utf8mb4_unicode_ci |
# | locadora | total_alugueis_cliente          | PROCEDURE | root@localhost | 2026-06-30 16:31:01 | 2026-06-30 16:31:01 | DEFINER       |         | utf8mb4              | utf8mb4_general_ci   | utf8mb4_unicode_ci |
# +----------+---------------------------------+-----------+----------------+---------------------+---------------------+---------------+---------+----------------------+----------------------+--------------------+
# +------------------+
# | etapa            |
# +------------------+
# | TRIGGERS CRIADAS |
# +------------------+
# +--------------------------------------+--------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+------------------------+-------------------------------------------------------------------------------------------+----------------+----------------------+----------------------+--------------------+
# | Trigger                              | Event  | Table     | Statement                                                                                                                                                                                                                                                                                                                                                                                                                                                                | Timing | Created                | sql_mode                                                                                  | Definer        | character_set_client | collation_connection | Database Collation |
# +--------------------------------------+--------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+------------------------+-------------------------------------------------------------------------------------------+----------------+----------------------+----------------------+--------------------+
# | trg_validar_preco_filme_insert       | INSERT | filme     | BEGIN
#     IF NEW.preco_da_locacao IS NULL
#        OR NEW.preco_da_locacao < 1.00 THEN
#
#         SIGNAL SQLSTATE '45000'
#         SET MESSAGE_TEXT =
#             'Preço de locação inválido. O valor mínimo permitido é R$ 1,00.';
#     END IF;
# END                                                                                                                                                                                                                           | BEFORE | 2026-06-30 16:31:01.42 | STRICT_TRANS_TABLES,ERROR_FOR_DIVISION_BY_ZERO,NO_AUTO_CREATE_USER,NO_ENGINE_SUBSTITUTION | root@localhost | utf8mb4              | utf8mb4_general_ci   | utf8mb4_unicode_ci |
# | trg_auditoria_filme_update           | UPDATE | filme     | BEGIN
#     INSERT INTO auditoria_filme (
#         filme_id,
#         titulo_anterior,
#         titulo_novo,
#         preco_anterior,
#         preco_novo,
#         data_alteracao,
#         tipo_operacao,
#         usuario_banco
#     ) VALUES (
#         OLD.filme_id,
#         OLD.titulo,
#         NEW.titulo,
#         OLD.preco_da_locacao,
#         NEW.preco_da_locacao,
#         CURRENT_TIMESTAMP,
#         'UPDATE',
#         CURRENT_USER()
#     );
# END                         | AFTER  | 2026-06-30 16:31:01.41 | STRICT_TRANS_TABLES,ERROR_FOR_DIVISION_BY_ZERO,NO_AUTO_CREATE_USER,NO_ENGINE_SUBSTITUTION | root@localhost | utf8mb4              | utf8mb4_general_ci   | utf8mb4_unicode_ci |
# | trg_atualizar_resumo_gasto_pagamento | INSERT | pagamento | BEGIN
#     INSERT INTO resumo_gasto_cliente (
#         cliente_id,
#         total_gasto,
#         quantidade_pagamentos,
#         atualizado_em
#     ) VALUES (
#         NEW.cliente_id,
#         NEW.valor,
#         1,
#         CURRENT_TIMESTAMP
#     )
#     ON DUPLICATE KEY UPDATE
#         total_gasto =
#             total_gasto + NEW.valor,
#         quantidade_pagamentos =
#             quantidade_pagamentos + 1,
#         atualizado_em =
#             CURRENT_TIMESTAMP;
# END | AFTER  | 2026-06-30 16:31:01.45 | STRICT_TRANS_TABLES,ERROR_FOR_DIVISION_BY_ZERO,NO_AUTO_CREATE_USER,NO_ENGINE_SUBSTITUTION | root@localhost | utf8mb4              | utf8mb4_general_ci   | utf8mb4_unicode_ci |
# +--------------------------------------+--------+-----------+--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+--------+------------------------+-------------------------------------------------------------------------------------------+----------------+----------------------+----------------------+--------------------+
#
# Atividade concluída.

# %% [markdown]
# ## Baixar o SQL final
# Antes da entrega, renomeie o arquivo conforme o padrão solicitado pelo professor.

# %%
from google.colab import files

# Renomeie o arquivo antes da entrega, substituindo NomeSobrenome.
files.download(
    "/content/NomeSobrenome_Sakila_SQL.sql"
)
